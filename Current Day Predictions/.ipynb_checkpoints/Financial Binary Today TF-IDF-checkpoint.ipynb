# %% [markdown]
# ### Financial Index Prediction
# This notebook seeks to predict the direction of a financial index from day k-1 to day k given financial news headlines from day k. A range of different combinations between statistical and NLP-models are used.

# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.utils import parallel_backend
from pathlib import Path
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from sklearn.metrics import classification_report, confusion_matrix, f1_score, plot_confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn import svm
from sklearn.dummy import DummyClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from xgboost import XGBClassifier

# %% [markdown]
# #### Load financial news data and financial index data

# %%
ONEDRIVE_PATH = Path(r"C:\Users\gusta\Kidbrooke Advisory Ab\KidbrookeOneDrive - Gustaf Backman exjobb")

# Read the financial data 
fin_path = ONEDRIVE_PATH / "Input Data/stock_data.pkl"
fin_data = pd.read_pickle(fin_path)
fin_data = fin_data.loc['2006-10-19' : '2013-11-22']

news_path = ONEDRIVE_PATH / "Input Data/financial_headlines_20061020-20131119.pkl"
news_data = pd.DataFrame(pd.read_pickle(news_path))
news_data.set_index('date',inplace=True)

# %%
news_dates = news_data.index.drop_duplicates()
fin_dates = fin_data.index.drop_duplicates

# Find the dates which are present in both the financial data and news data
valid_dates = []
for date in news_dates: 
    if date in fin_data.index: 
        valid_dates.append(date)
        
# Create targets for all 3 time series 
targets = pd.DataFrame(dtype='int8')
prev_vals = fin_data.iloc[0]
for date in valid_dates: 
    y_temp = []
    # If the value has increased since yesterday, y = 1
    if prev_vals['1 YEAR'] < fin_data.loc[date]['1 YEAR']: 
        y_temp.append(1)
    else:
        y_temp.append(0)
        
    if prev_vals['3 YEAR'] < fin_data.loc[date]['3 YEAR']: 
        y_temp.append(1)
    else:
        y_temp.append(0)
        
    if prev_vals['S&P'] < fin_data.loc[date]['S&P']: 
        y_temp.append(1)
    else:
        y_temp.append(0)
    targets = targets.append({'1 YEAR':y_temp[0], '3 YEAR':y_temp[1], 'S&P':y_temp[2]}, ignore_index=True)
    prev_vals = fin_data.loc[date]

# %%
# Concatenate the news for each day in the valid indices, i.e. the indices that are present in both 
# the financial data and the news data 
texts = []
for date in valid_dates: 
    temp_texts = ""
    for i,text in enumerate(news_data.loc[date]['title']): 
        if i < len(news_data.loc[date]['title']) - 1:
            temp_texts += text + ". "
        else:
            temp_texts += text
    texts.append(temp_texts)
texts = np.asarray(texts)
print("Length of texts:",len(texts))
print("Length of targets:",len(targets))
# Out:
# Length of texts: 1846
# Length of targets: 1846

# %% [markdown]
# #### Format the text with tf-idf
# The texts have now been separated into entries in a arrays for training and testing. The next step is to transform these entries into vectors using TF-IDF.

# %%
# Create a matrix with the frequency of a word in each day.
count_vec = CountVectorizer(max_features=10000) # Includes only the 10000 most frequent words 
count_vec.fit(texts)

x_count = count_vec.transform(texts)
x_count = count_vec.transform(texts)

# Create a matrix with the tfidf representation of the text
tfidf_vec = TfidfTransformer()
tfidf_vec.fit(x_count)
x = tfidf_vec.transform(x_count)

# %% [markdown]
# #### Partition into training and test set
# Since the data is somewhat imbalanced - mostly for the 1 year rate - the training data will be under sampled by the minority class.

# %%
zero_indices_1yr = np.where(targets['1 YEAR'] == 0)[0]
one_indices_1yr = np.where(targets['1 YEAR'] == 1)[0]

zero_indices_3yr = np.where(targets['3 YEAR'] == 0)[0]
one_indices_3yr = np.where(targets['3 YEAR'] == 1)[0]

zero_indices_sp = np.where(targets['S&P'] == 0)[0]
one_indices_sp = np.where(targets['S&P'] == 1)[0]

print(" ----- 1 YEAR RATE -----")
print("Ratio neg labels 1 year rate:",len(zero_indices_1yr) / len(targets))
print("Neg labels:", len(zero_indices_1yr), "Pos labels:",len(one_indices_1yr))
print(" ----- 3 YEAR RATE -----")
print("Ratio neg labels 3 year rate:",len(zero_indices_3yr) / len(targets))
print("Neg labels:", len(zero_indices_3yr), "Pos labels:",len(one_indices_3yr))
print(" -----     S&P     -----")
print("Ratio neg labels S&P:",len(zero_indices_sp) / len(targets))
print("Neg labels:", len(zero_indices_sp), "Pos labels:",len(one_indices_sp))
# Out:
#  ----- 1 YEAR RATE -----
# Ratio neg labels 1 year rate: 0.6885157096424702
# Neg labels: 1271 Pos labels: 575
#  ----- 3 YEAR RATE -----
# Ratio neg labels 3 year rate: 0.5937161430119177
# Neg labels: 1096 Pos labels: 750
#  -----     S&P     -----
# Ratio neg labels S&P: 0.46424702058504874
# Neg labels: 857 Pos labels: 989

# %%
n_train = 1000

np.random.shuffle(zero_indices_1yr)
np.random.shuffle(one_indices_1yr)
train_indices_1yr = np.zeros((n_train),dtype=int)
train_indices_1yr[:int(n_train / 2)] = zero_indices_1yr[:int(n_train / 2)]
train_indices_1yr[int(n_train / 2):] = one_indices_1yr[:int(n_train / 2)]
np.random.shuffle(train_indices_1yr)
test_indices_1yr = np.setdiff1d(np.arange(len(targets)), train_indices_1yr)
np.random.shuffle(test_indices_1yr)

np.random.shuffle(zero_indices_3yr)
np.random.shuffle(one_indices_3yr)
train_indices_3yr = np.zeros((n_train),dtype=int)
train_indices_3yr[:int(n_train / 2)] = zero_indices_3yr[:int(n_train / 2)]
train_indices_3yr[int(n_train / 2):] = one_indices_3yr[:int(n_train / 2)]
np.random.shuffle(train_indices_3yr)
test_indices_3yr = np.setdiff1d(np.arange(len(targets)), train_indices_3yr)
np.random.shuffle(test_indices_3yr)

np.random.shuffle(zero_indices_sp)
np.random.shuffle(one_indices_sp)
train_indices_sp = np.zeros((n_train),dtype=int)
train_indices_sp[:int(n_train / 2)] = zero_indices_sp[:int(n_train / 2)]
train_indices_sp[int(n_train / 2):] = one_indices_sp[:int(n_train / 2)]
np.random.shuffle(train_indices_sp)
test_indices_sp = np.setdiff1d(np.arange(len(targets)), train_indices_sp)
np.random.shuffle(test_indices_sp)

texts_train_1yr = texts[train_indices_1yr]
texts_test_1yr = texts[test_indices_1yr]
x_train_1yr = x[train_indices_1yr]
x_test_1yr = x[test_indices_1yr]
y_train_1yr = targets.iloc[train_indices_1yr]['1 YEAR'].values
y_test_1yr = targets.iloc[test_indices_1yr]['1 YEAR'].values

texts_train_3yr = texts[train_indices_3yr]
texts_test_3yr = texts[test_indices_3yr]
x_train_3yr = x[train_indices_3yr]
x_test_3yr = x[test_indices_3yr]
y_train_3yr = targets.iloc[train_indices_3yr]['3 YEAR'].values
y_test_3yr = targets.iloc[test_indices_3yr]['3 YEAR'].values

texts_train_sp = texts[train_indices_sp]
texts_test_sp = texts[test_indices_sp]
x_train_sp = x[train_indices_sp]
x_test_sp = x[test_indices_sp]
y_train_sp = targets.iloc[train_indices_sp]['S&P'].values
y_test_sp = targets.iloc[test_indices_sp]['S&P'].values

# Sanity check of shapes 

print(" ----- 1 YEAR RATE -----")
print("Train data shape (x,y):",x_train_1yr.shape,",", y_train_1yr.shape)
print("Train data label ratio (0 / 1):",np.sum(y_train_1yr == 0),"/", np.sum(y_train_1yr == 1))
print("Test data shape (x,y):",x_test_1yr.shape,",", y_test_1yr.shape)
print("Test data label ratio (0 / 1):",np.sum(y_test_1yr == 0),"/", np.sum(y_test_1yr == 1))

print(" ----- 3 YEAR RATE -----")
print("Train data shape (x,y):",x_train_3yr.shape,",", y_train_3yr.shape)
print("Train data label ratio (0 / 1):",np.sum(y_train_3yr == 0),"/", np.sum(y_train_3yr == 1))
print("Test data shape (x,y):",x_test_3yr.shape,",", y_test_3yr.shape)
print("Test data label ratio (0 / 1):",np.sum(y_test_3yr == 0),"/", np.sum(y_test_3yr == 1))
print(" -----     S&P     -----")
print("Train data shape (x,y):",x_train_sp.shape,",", y_train_sp.shape)
print("Train data label ratio (0 / 1):",np.sum(y_train_sp == 0),"/", np.sum(y_train_sp == 1))
print("Test data shape (x,y):",x_test_sp.shape,",", y_test_sp.shape)
print("Test data label ratio (0 / 1):",np.sum(y_test_sp == 0),"/", np.sum(y_test_sp == 1))
# Out:
#  ----- 1 YEAR RATE -----
# Train data shape (x,y): (1000, 10000) , (1000,)
# Train data label ratio (0 / 1): 500 / 500
# Test data shape (x,y): (846, 10000) , (846,)
# Test data label ratio (0 / 1): 771 / 75
#  ----- 3 YEAR RATE -----
# Train data shape (x,y): (1000, 10000) , (1000,)
# Train data label ratio (0 / 1): 500 / 500
# Test data shape (x,y): (846, 10000) , (846,)
# Test data label ratio (0 / 1): 596 / 250
#  -----     S&P     -----
# Train data shape (x,y): (1000, 10000) , (1000,)
# Train data label ratio (0 / 1): 500 / 500
# Test data shape (x,y): (846, 10000) , (846,)
# Test data label ratio (0 / 1): 357 / 489

# %% [markdown]
# ## Models
# The data has been pre-processed and the models can be evaluated. All of the models are fitted with the three data series.

# %%
# Some help functions for plotting the results 

def plot_results(model,x_test, y_test,save=False, name=''):
    y_test_preds = model.predict(x_test)
    print(classification_report(y_test, y_test_preds))
    print("Test accuracy:",model.score(x_test, y_test))
    plot_confusion_matrix(model,x_test,y_test)
    if save:
        plt.savefig("Figs TF-IDF/" + name + "confmat.jpg")
    plt.show()
    
def plot_results_nn(history, model,x_test, y_test,save=False, name=''):
    plt.subplot(121)
    plt.plot(history.history['loss'],label='Loss')
    plt.plot(history.history['val_loss'],label='Val loss')
    plt.legend()
    plt.subplot(122)
    plt.plot(history.history['acc'],label='Acc')
    plt.plot(history.history['val_acc'],label='Val acc')
    plt.legend()
    if save: 
        plt.savefig("Figs TF-IDF/" + name + "history.jpg")
    plt.show() 
    y_test_pred = np.round(model.predict(x_test.todense()))
    plt.subplot(121)
    plt.bar([0,1],[np.sum(y_test == 0), np.sum(y_test == 1)], label='Actual test dist')
    plt.legend()
    plt.xticks([0, 1])
    plt.subplot(122)
    plt.bar([0,1],[np.sum(y_test_pred == 0), np.sum(y_test_pred == 1)], label='Pred test dist')
    plt.legend()
    plt.xticks([0, 1])
    plt.show()
    conf_mat = confusion_matrix(y_test,y_test_pred,normalize='pred')
    ax = sn.heatmap(conf_mat,)
    ax.set_ylabel("True values")
    ax.set_xlabel("Predicted values")
    if save: 
        plt.savefig("Figs TF-IDF/" + name + "confmat.jpg")
    plt.show()
    print(classification_report(y_test, y_test_pred))
    print("Test accuracy:",round(np.sum(y_test == y_test_pred[:,0]) / len(y_test),3))

# %% [markdown]
# ### Random Classifier
# Just for real simple comparison.
# #### 1 year rate

# %%
# Dummy Classifier
dummy_clf_1yr = DummyClassifier().fit(x_train_1yr, y_train_1yr)
plot_results(dummy_clf, x_test_1yr, y_test_1yr,save=True,name='randclf_1yr')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.52      0.66       771
#          1.0       0.09      0.49      0.15        75
#
#     accuracy                           0.52       846
#    macro avg       0.50      0.51      0.41       846
# weighted avg       0.84      0.52      0.62       846
#
# Test accuracy: 0.48699763593380613

# %% [markdown]
# #### 3 year rate

# %%
# Dummy Classifier
dummy_clf_3yr = DummyClassifier().fit(x_train_3yr, y_train_3yr)
plot_results(dummy_clf_3yr, x_test_3yr, y_test_3yr,save=True,name='randclf_3yr')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.48      0.56       596
#          1.0       0.28      0.48      0.35       250
#
#     accuracy                           0.48       846
#    macro avg       0.48      0.48      0.46       846
# weighted avg       0.57      0.48      0.50       846
#
# Test accuracy: 0.533096926713948

# %% [markdown]
# #### S&P

# %%
# Dummy Classifier
dummy_clf_sp = DummyClassifier().fit(x_train_sp, y_train_sp)
plot_results(dummy_clf_sp, x_test_sp, y_test_sp,save=True,name='randclf_sp')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.54      0.48       357
#          1.0       0.58      0.47      0.52       489
#
#     accuracy                           0.50       846
#    macro avg       0.50      0.50      0.50       846
# weighted avg       0.52      0.50      0.50       846
#
# Test accuracy: 0.491725768321513

# %% [markdown]
# ### Logistic Regression with TF-IDF
# #### 1 year rate

# %%
# Logistic regression
logreg_1yr = LogisticRegression(random_state=0).fit(x_train_1yr, y_train_1yr)
plot_results(logreg_1yr,x_test_1yr, y_test_1yr,save=True,name='logreg_1yr')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.54      0.68       771
#          1.0       0.10      0.55      0.17        75
#
#     accuracy                           0.54       846
#    macro avg       0.51      0.54      0.43       846
# weighted avg       0.85      0.54      0.64       846
#
# Test accuracy: 0.5401891252955082

# %% [markdown]
# #### 3 year rate

# %%
# Logistic regression
logreg_3yr = LogisticRegression(random_state=0).fit(x_train_3yr, y_train_3yr)
plot_results(logreg_3yr,x_test_3yr, y_test_3yr,save=True,name='logreg_3yr')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.54      0.62       596
#          1.0       0.32      0.52      0.40       250
#
#     accuracy                           0.53       846
#    macro avg       0.53      0.53      0.51       846
# weighted avg       0.61      0.53      0.55       846
#
# Test accuracy: 0.533096926713948

# %% [markdown]
# #### S&P

# %%
# Logistic regression
logreg_sp = LogisticRegression(random_state=0).fit(x_train_sp, y_train_sp)
plot_results(logreg_sp,x_test_sp, y_test_sp,save=True,name='logreg_sp')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.56      0.53       357
#          1.0       0.65      0.59      0.62       489
#
#     accuracy                           0.58       846
#    macro avg       0.57      0.57      0.57       846
# weighted avg       0.58      0.58      0.58       846
#
# Test accuracy: 0.5768321513002365

# %% [markdown]
# ### Support Vector Machine with TF-IDF
# #### 1 year rate

# %%
svm_clf_1yr = svm.SVC().fit(x_train_1yr, y_train_1yr)
plot_results(svm_clf_1yr, x_test_1yr, y_test_1yr,save=True,name='svm_1yr')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.52      0.66       771
#          1.0       0.11      0.59      0.18        75
#
#     accuracy                           0.52       846
#    macro avg       0.52      0.55      0.42       846
# weighted avg       0.86      0.52      0.62       846
#
# Test accuracy: 0.5236406619385343

# %% [markdown]
# #### 3 year rate

# %%
svm_clf_3yr = svm.SVC().fit(x_train_3yr, y_train_3yr)
plot_results(svm_clf_3yr, x_test_3yr, y_test_3yr,save=True,name='svm_3yr')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.50      0.60       596
#          1.0       0.33      0.59      0.42       250
#
#     accuracy                           0.53       846
#    macro avg       0.54      0.55      0.51       846
# weighted avg       0.62      0.53      0.55       846
#
# Test accuracy: 0.5260047281323877

# %% [markdown]
# #### S&P

# %%
svm_clf_sp = svm.SVC().fit(x_train_sp, y_train_sp)
plot_results(svm_clf_sp, x_test_sp, y_test_sp,save=True,name='svm_sp')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.49      0.52      0.50       357
#          1.0       0.63      0.61      0.62       489
#
#     accuracy                           0.57       846
#    macro avg       0.56      0.56      0.56       846
# weighted avg       0.57      0.57      0.57       846
#
# Test accuracy: 0.5673758865248227

# %% [markdown]
# ### Random Forest with TF-IDF
# #### 1 year rate

# %%
# Random Forest
rf_param_grid = dict(max_depth=[None, 50, 100],
                  n_estimators=[250, 500, 750, 1000])
rf_grid = GridSearchCV(estimator=RandomForestClassifier(), 
                       param_grid=rf_param_grid, 
                       n_jobs=-1, 
                       cv=10, 
                       scoring='f1_weighted',
                       verbose=1)
with parallel_backend('threading'):    # This is a bug work-around mentioned in https://github.com/scikit-learn/scikit-learn/issues/12546
    rf_grid_result = rf_grid.fit(x_train_1yr, y_train_1yr)
# summarize results
print("Best: %f using %s" % (rf_grid_result.best_score_, rf_grid_result.best_params_))
rf_means = rf_grid_result.cv_results_['mean_test_score']
rf_stds = rf_grid_result.cv_results_['std_test_score']
rf_params = rf_grid_result.cv_results_['params']
for mean, stdev, param in zip(rf_means, rf_stds, rf_params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# Fit the model with the best parameters found in the cross validation. 
randomforest_1yr = RandomForestClassifier(max_depth=rf_grid_result.best_params_['max_depth'],
                                      n_estimators=rf_grid_result.best_params_['n_estimators']).fit(x_train_1yr, y_train_1yr)
plot_results(randomforest_1yr,x_test_1yr, y_test_1yr,save=True,name='rf_1yr_md{}_est_{}'.format(rf_grid_result.best_params_['max_depth'],
                                                                                rf_grid_result.best_params_['n_estimators']))
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   59.4s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:  3.6min finished
# Best: 0.548293 using {'max_depth': None, 'n_estimators': 500}
# 0.540491 (0.053876) with: {'max_depth': None, 'n_estimators': 250}
# 0.548293 (0.031068) with: {'max_depth': None, 'n_estimators': 500}
# 0.547621 (0.063388) with: {'max_depth': None, 'n_estimators': 750}
# 0.535935 (0.055468) with: {'max_depth': None, 'n_estimators': 1000}
# 0.546860 (0.049513) with: {'max_depth': 50, 'n_estimators': 250}
# 0.530882 (0.066365) with: {'max_depth': 50, 'n_estimators': 500}
# 0.526982 (0.060436) with: {'max_depth': 50, 'n_estimators': 750}
# 0.542617 (0.045813) with: {'max_depth': 50, 'n_estimators': 1000}
# 0.524840 (0.031370) with: {'max_depth': 100, 'n_estimators': 250}
# 0.529373 (0.036537) with: {'max_depth': 100, 'n_estimators': 500}
# 0.538012 (0.039803) with: {'max_depth': 100, 'n_estimators': 750}
# 0.528069 (0.060044) with: {'max_depth': 100, 'n_estimators': 1000}
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.52      0.66       771
#          1.0       0.10      0.53      0.16        75
#
#     accuracy                           0.52       846
#    macro avg       0.51      0.53      0.41       846
# weighted avg       0.85      0.52      0.62       846
#
# Test accuracy: 0.5212765957446809

# %% [markdown]
# #### 3 year rate

# %%
# Random Forest
rf_param_grid = dict(max_depth=[None, 50, 100],
                  n_estimators=[250, 500, 750, 1000])
rf_grid = GridSearchCV(estimator=RandomForestClassifier(), 
                       param_grid=rf_param_grid, 
                       n_jobs=-1, 
                       cv=10, 
                       scoring='f1_weighted',
                       verbose=1)
with parallel_backend('threading'):    # This is a bug work-around mentioned in https://github.com/scikit-learn/scikit-learn/issues/12546
    rf_grid_result = rf_grid.fit(x_train_3yr, y_train_3yr)
# summarize results
print("Best: %f using %s" % (rf_grid_result.best_score_, rf_grid_result.best_params_))
rf_means = rf_grid_result.cv_results_['mean_test_score']
rf_stds = rf_grid_result.cv_results_['std_test_score']
rf_params = rf_grid_result.cv_results_['params']
for mean, stdev, param in zip(rf_means, rf_stds, rf_params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# Fit the model with the best parameters found in the cross validation. 
randomforest_3yr = RandomForestClassifier(max_depth=rf_grid_result.best_params_['max_depth'],
                                      n_estimators=rf_grid_result.best_params_['n_estimators']).fit(x_train_3yr, y_train_3yr)
plot_results(randomforest_3yr,x_test_3yr, y_test_3yr,save=True,name='rf_3yr_md{}_est_{}'.format(rf_grid_result.best_params_['max_depth'],
                                                                                rf_grid_result.best_params_['n_estimators']))
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:  5.9min finished
# Best: 0.535708 using {'max_depth': 100, 'n_estimators': 1000}
# 0.523979 (0.022219) with: {'max_depth': None, 'n_estimators': 250}
# 0.527407 (0.056636) with: {'max_depth': None, 'n_estimators': 500}
# 0.517968 (0.021751) with: {'max_depth': None, 'n_estimators': 750}
# 0.517112 (0.044896) with: {'max_depth': None, 'n_estimators': 1000}
# 0.507378 (0.036474) with: {'max_depth': 50, 'n_estimators': 250}
# 0.526189 (0.056350) with: {'max_depth': 50, 'n_estimators': 500}
# 0.506243 (0.047924) with: {'max_depth': 50, 'n_estimators': 750}
# 0.521810 (0.026526) with: {'max_depth': 50, 'n_estimators': 1000}
# 0.531422 (0.049184) with: {'max_depth': 100, 'n_estimators': 250}
# 0.523983 (0.043410) with: {'max_depth': 100, 'n_estimators': 500}
# 0.508772 (0.038853) with: {'max_depth': 100, 'n_estimators': 750}
# 0.535708 (0.031050) with: {'max_depth': 100, 'n_estimators': 1000}
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.51      0.60       596
#          1.0       0.32      0.55      0.40       250
#
#     accuracy                           0.52       846
#    macro avg       0.52      0.53      0.50       846
# weighted avg       0.61      0.52      0.54       846
#
# Test accuracy: 0.5189125295508275

# %% [markdown]
# #### S&P

# %%
# Random Forest
rf_param_grid = dict(max_depth=[None, 50, 100],
                  n_estimators=[250, 500, 750, 1000])
rf_grid = GridSearchCV(estimator=RandomForestClassifier(), 
                       param_grid=rf_param_grid, 
                       n_jobs=-1, 
                       cv=10, 
                       scoring='f1_weighted',
                       verbose=1)
with parallel_backend('threading'):    # This is a bug work-around mentioned in https://github.com/scikit-learn/scikit-learn/issues/12546
    rf_grid_result = rf_grid.fit(x_train_sp, y_train_sp)
# summarize results
print("Best: %f using %s" % (rf_grid_result.best_score_, rf_grid_result.best_params_))
rf_means = rf_grid_result.cv_results_['mean_test_score']
rf_stds = rf_grid_result.cv_results_['std_test_score']
rf_params = rf_grid_result.cv_results_['params']
for mean, stdev, param in zip(rf_means, rf_stds, rf_params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# Fit the model with the best parameters found in the cross validation. 
randomforest_sp = RandomForestClassifier(max_depth=rf_grid_result.best_params_['max_depth'],
                                      n_estimators=rf_grid_result.best_params_['n_estimators']).fit(x_train_sp, y_train_sp)
plot_results(randomforest_sp,x_test_sp, y_test_sp,save=True,name='rf_sp_md{}_est_{}'.format(rf_grid_result.best_params_['max_depth'],
                                                                                rf_grid_result.best_params_['n_estimators']))
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:  8.3min finished
# Best: 0.610964 using {'max_depth': 50, 'n_estimators': 1000}
# 0.583307 (0.058467) with: {'max_depth': None, 'n_estimators': 250}
# 0.579783 (0.031138) with: {'max_depth': None, 'n_estimators': 500}
# 0.581107 (0.051311) with: {'max_depth': None, 'n_estimators': 750}
# 0.578151 (0.043081) with: {'max_depth': None, 'n_estimators': 1000}
# 0.579922 (0.047931) with: {'max_depth': 50, 'n_estimators': 250}
# 0.607271 (0.028881) with: {'max_depth': 50, 'n_estimators': 500}
# 0.605632 (0.044780) with: {'max_depth': 50, 'n_estimators': 750}
# 0.610964 (0.046805) with: {'max_depth': 50, 'n_estimators': 1000}
# 0.576008 (0.025423) with: {'max_depth': 100, 'n_estimators': 250}
# 0.589233 (0.066023) with: {'max_depth': 100, 'n_estimators': 500}
# 0.601054 (0.038425) with: {'max_depth': 100, 'n_estimators': 750}
# 0.582703 (0.039556) with: {'max_depth': 100, 'n_estimators': 1000}
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.59      0.59       357
#          1.0       0.70      0.70      0.70       489
#
#     accuracy                           0.65       846
#    macro avg       0.64      0.64      0.64       846
# weighted avg       0.65      0.65      0.65       846
#
# Test accuracy: 0.6524822695035462

# %% [markdown]
# ### XGBoost with TF-IDF
# #### 1 year rate

# %%
# Hyperparameter search
xg_param_grid = dict(n_estimators=[50, 100, 250, 500, 750, 1000])
xg_grid = GridSearchCV(estimator=XGBClassifier(), 
                       param_grid=xg_param_grid, 
                       n_jobs=-1, 
                       cv=10, 
                       scoring='f1_weighted',
                       verbose=5)
with parallel_backend('threading'):    # This is a bug work-around mentioned in https://github.com/scikit-learn/scikit-learn/issues/12546
    xg_grid_result = xg_grid.fit(x_train_1yr, y_train_1yr)

print("Best: %f using %s" % (xg_grid_result.best_score_, xg_grid_result.best_params_))
xg_means = xg_grid_result.cv_results_['mean_test_score']
xg_stds = xg_grid_result.cv_results_['std_test_score']
xg_params = xg_grid_result.cv_results_['params']
for mean, stdev, param in zip(xg_means, xg_stds, xg_params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# Fit the best model 
xgb_1yr = XGBClassifier(n_estimators=xg_grid_result.best_params_['n_estimators']).fit(x_train_1yr, y_train_1yr)
plot_results(xgb_1yr,x_test_1yr, y_test_1yr,save=True,name='xgb_1yr_est{}'.format(xg_grid_result.best_params_['n_estimators']))
# Out:
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# [CV] n_estimators=50 .................................................
# [CV] n_estimators=50 .................................................
# [CV] n_estimators=50 .................................................
# [CV] n_estimators=50 .................................................
# [CV] n_estimators=50 .................................................
# [CV] n_estimators=50 .................................................
# [CV] n_estimators=50 .................................................[CV] n_estimators=50 .................................................
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [CV] ..................... n_estimators=50, score=0.540, total=   9.2s
# [CV] n_estimators=50 .................................................
# [CV] ..................... n_estimators=50, score=0.420, total=   9.3s
# [CV] n_estimators=50 .................................................
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    9.2s
# [CV] ..................... n_estimators=50, score=0.549, total=   9.8s
# [CV] n_estimators=100 ................................................
# [CV] ..................... n_estimators=50, score=0.597, total=  10.0s
# [CV] n_estimators=100 ................................................[CV] ..................... n_estimators=50, score=0.484, total=  10.0s
#
# [CV] n_estimators=100 ................................................
# [CV] ..................... n_estimators=50, score=0.500, total=  10.0s
# [CV] n_estimators=100 ................................................
# [CV] ..................... n_estimators=50, score=0.447, total=  12.0s
# [CV] n_estimators=100 ................................................
# [CV] ..................... n_estimators=50, score=0.481, total=  13.4s
# [CV] n_estimators=100 ................................................
# [CV] ..................... n_estimators=50, score=0.470, total=   9.0s
# [CV] n_estimators=100 ................................................
# [CV] ..................... n_estimators=50, score=0.610, total=   9.4s
# [CV] n_estimators=100 ................................................
# [CV] .................... n_estimators=100, score=0.517, total=  16.7s
# [CV] .................... n_estimators=100, score=0.450, total=  17.3s[CV] n_estimators=100 ................................................
#
# [CV] .................... n_estimators=100, score=0.506, total=  17.1s[CV] n_estimators=100 ................................................
#
# [CV] n_estimators=250 ................................................
# [CV] .................... n_estimators=100, score=0.548, total=  17.7s
# [CV] n_estimators=250 ................................................
# [CV] .................... n_estimators=100, score=0.497, total=  17.3s
# [CV] n_estimators=250 ................................................
# [CV] .................... n_estimators=100, score=0.472, total=  17.6s
# [CV] n_estimators=250 ................................................
# [CV] .................... n_estimators=100, score=0.550, total=  17.0s
# [CV] n_estimators=250 ................................................
# [CV] .................... n_estimators=100, score=0.588, total=  17.8s
# [CV] n_estimators=250 ................................................
# [CV] .................... n_estimators=100, score=0.490, total=  16.3s
# [CV] n_estimators=250 ................................................
# [CV] .................... n_estimators=100, score=0.589, total=  17.2s
# [CV] n_estimators=250 ................................................
# [CV] .................... n_estimators=250, score=0.460, total=  39.5s
# [CV] n_estimators=250 ................................................
# [CV] .................... n_estimators=250, score=0.580, total=  39.7s
# [CV] n_estimators=250 ................................................
# [CV] .................... n_estimators=250, score=0.497, total=  39.2s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=250, score=0.508, total=  42.5s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=250, score=0.508, total=  39.3s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=250, score=0.489, total=  40.6s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=250, score=0.548, total=  41.2s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=250, score=0.466, total=  49.7s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=250, score=0.540, total=  42.7s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=250, score=0.480, total=  45.5s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=500, score=0.519, total= 1.3min
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=500, score=0.529, total= 1.4min
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=500, score=0.533, total= 1.3min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=500, score=0.450, total= 1.5min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=500, score=0.436, total= 1.3min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=500, score=0.490, total= 1.4min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=500, score=0.518, total= 1.3min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=500, score=0.530, total= 1.4min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=500, score=0.550, total= 1.3min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=500, score=0.490, total= 1.6min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=750, score=0.479, total= 2.0min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=750, score=0.558, total= 2.0min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=750, score=0.546, total= 1.9min
# [CV] n_estimators=1000 ...............................................
# [CV] .................... n_estimators=750, score=0.530, total= 2.2min
# [CV] n_estimators=1000 ...............................................
# [CV] .................... n_estimators=750, score=0.420, total= 1.9min
# [CV] n_estimators=1000 ...............................................
# [CV] .................... n_estimators=750, score=0.489, total= 2.0min
# [CV] n_estimators=1000 ...............................................
# [CV] .................... n_estimators=750, score=0.490, total= 2.0min
# [CV] n_estimators=1000 ...............................................
# [CV] .................... n_estimators=750, score=0.550, total= 2.1min
# [CV] n_estimators=1000 ...............................................
# [CV] .................... n_estimators=750, score=0.470, total= 2.0min
# [CV] n_estimators=1000 ...............................................
# [CV] .................... n_estimators=750, score=0.519, total= 2.1min
# [CV] n_estimators=1000 ...............................................
# [CV] ................... n_estimators=1000, score=0.530, total= 2.5min
# [CV] n_estimators=1000 ...............................................
# [CV] ................... n_estimators=1000, score=0.570, total= 2.5min
# [CV] n_estimators=1000 ...............................................
# [CV] ................... n_estimators=1000, score=0.526, total= 2.5min
# [CV] ................... n_estimators=1000, score=0.520, total= 2.8min
# [CV] ................... n_estimators=1000, score=0.420, total= 2.4min
# [CV] ................... n_estimators=1000, score=0.509, total= 2.3min
# [CV] ................... n_estimators=1000, score=0.528, total= 2.2min
# [CV] ................... n_estimators=1000, score=0.549, total= 2.1min
# [Parallel(n_jobs=-1)]: Done  58 out of  60 | elapsed:  8.8min remaining:   18.2s
# [CV] ................... n_estimators=1000, score=0.498, total= 1.8min
# [CV] ................... n_estimators=1000, score=0.440, total= 2.1min
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  9.5min finished
# Best: 0.520632 using {'n_estimators': 100}
# 0.509830 (0.059404) with: {'n_estimators': 50}
# 0.520632 (0.044546) with: {'n_estimators': 100}
# 0.507375 (0.036278) with: {'n_estimators': 250}
# 0.504496 (0.035456) with: {'n_estimators': 500}
# 0.505028 (0.041256) with: {'n_estimators': 750}
# 0.508823 (0.043953) with: {'n_estimators': 1000}
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.53      0.67       771
#          1.0       0.10      0.52      0.16        75
#
#     accuracy                           0.53       846
#    macro avg       0.51      0.53      0.42       846
# weighted avg       0.85      0.53      0.63       846
#
# Test accuracy: 0.5319148936170213

# %% [markdown]
# #### 3 year rate

# %%
# Hyperparameter search
xg_param_grid = dict(n_estimators=[50, 100, 250, 500, 750, 1000])
xg_grid = GridSearchCV(estimator=XGBClassifier(), 
                       param_grid=xg_param_grid, 
                       n_jobs=-1, 
                       cv=10, 
                       scoring='f1_weighted',
                       verbose=5)
with parallel_backend('threading'):    # This is a bug work-around mentioned in https://github.com/scikit-learn/scikit-learn/issues/12546
    xg_grid_result = xg_grid.fit(x_train_3yr, y_train_3yr)

print("Best: %f using %s" % (xg_grid_result.best_score_, xg_grid_result.best_params_))
xg_means = xg_grid_result.cv_results_['mean_test_score']
xg_stds = xg_grid_result.cv_results_['std_test_score']
xg_params = xg_grid_result.cv_results_['params']
for mean, stdev, param in zip(xg_means, xg_stds, xg_params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# Fit the best model 
xgb_3yr = XGBClassifier(n_estimators=xg_grid_result.best_params_['n_estimators']).fit(x_train_3yr, y_train_3yr)
plot_results(xgb_3yr,x_test_3yr, y_test_3yr,save=True,name='xgb_3yr_est{}'.format(xg_grid_result.best_params_['n_estimators']))
# Out:
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=250, score=0.548, total=  41.3s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=250, score=0.440, total=  42.2s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=500, score=0.580, total= 1.3min
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=500, score=0.520, total= 1.3min
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=500, score=0.499, total= 1.3min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=500, score=0.528, total= 1.4min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=500, score=0.416, total= 1.4min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=500, score=0.479, total= 1.4min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=500, score=0.459, total= 1.3min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=500, score=0.550, total= 1.3min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=500, score=0.589, total= 1.4min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=500, score=0.520, total= 1.4min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=750, score=0.570, total= 1.9min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=750, score=0.539, total= 1.9min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=750, score=0.518, total= 2.0min
# [CV] n_estimators=1000 ...............................................
# [CV] .................... n_estimators=750, score=0.470, total= 2.0min
# [CV] n_estimators=1000 ...............................................
# [CV] .................... n_estimators=750, score=0.419, total= 1.9min
# [CV] n_estimators=1000 ...............................................
# [CV] .................... n_estimators=750, score=0.518, total= 2.0min
# [CV] n_estimators=1000 ...............................................
# [CV] .................... n_estimators=750, score=0.490, total= 2.0min
# [CV] n_estimators=1000 ...............................................
# [CV] .................... n_estimators=750, score=0.540, total= 2.0min
# [CV] n_estimators=1000 ...............................................
# [CV] .................... n_estimators=750, score=0.569, total= 1.9min
# [CV] n_estimators=1000 ...............................................
# [CV] .................... n_estimators=750, score=0.510, total= 1.9min
# [CV] n_estimators=1000 ...............................................
# [CV] ................... n_estimators=1000, score=0.580, total= 2.5min
# [CV] n_estimators=1000 ...............................................
# [CV] ................... n_estimators=1000, score=0.530, total= 2.5min
# [CV] n_estimators=1000 ...............................................
# [CV] ................... n_estimators=1000, score=0.566, total= 2.5min
# [CV] ................... n_estimators=1000, score=0.470, total= 2.5min
# [CV] ................... n_estimators=1000, score=0.429, total= 2.4min
# [CV] ................... n_estimators=1000, score=0.509, total= 2.5min
# [CV] ................... n_estimators=1000, score=0.540, total= 2.1min
# [CV] ................... n_estimators=1000, score=0.510, total= 2.2min
# [Parallel(n_jobs=-1)]: Done  58 out of  60 | elapsed:  8.6min remaining:   17.7s
# [CV] ................... n_estimators=1000, score=0.580, total= 1.8min
# [CV] ................... n_estimators=1000, score=0.490, total= 1.8min
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  9.1min finished
# Best: 0.520272 using {'n_estimators': 1000}
# 0.505708 (0.039057) with: {'n_estimators': 50}
# 0.498886 (0.031063) with: {'n_estimators': 100}
# 0.501907 (0.044602) with: {'n_estimators': 250}
# 0.514019 (0.050519) with: {'n_estimators': 500}
# 0.514298 (0.043672) with: {'n_estimators': 750}
# 0.520272 (0.046706) with: {'n_estimators': 1000}
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.54      0.62       596
#          1.0       0.32      0.52      0.40       250
#
#     accuracy                           0.53       846
#    macro avg       0.52      0.53      0.51       846
# weighted avg       0.61      0.53      0.55       846
#
# Test accuracy: 0.5319148936170213

# %% [markdown]
# #### S&P

# %%
# Hyperparameter search
xg_param_grid = dict(n_estimators=[50, 100, 250, 500, 750, 1000])
xg_grid = GridSearchCV(estimator=XGBClassifier(), 
                       param_grid=xg_param_grid, 
                       n_jobs=-1, 
                       cv=10, 
                       scoring='f1_weighted',
                       verbose=5)
with parallel_backend('threading'):    # This is a bug work-around mentioned in https://github.com/scikit-learn/scikit-learn/issues/12546
    xg_grid_result = xg_grid.fit(x_train_sp, y_train_sp)

print("Best: %f using %s" % (xg_grid_result.best_score_, xg_grid_result.best_params_))
xg_means = xg_grid_result.cv_results_['mean_test_score']
xg_stds = xg_grid_result.cv_results_['std_test_score']
xg_params = xg_grid_result.cv_results_['params']
for mean, stdev, param in zip(xg_means, xg_stds, xg_params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# Fit the best model 
xgb_sp = XGBClassifier(n_estimators=xg_grid_result.best_params_['n_estimators']).fit(x_train_sp, y_train_sp)
plot_results(xgb_sp,x_test_sp, y_test_sp,save=True,name='xgb_sp_est{}'.format(xg_grid_result.best_params_['n_estimators']))
# Out:
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# [CV] n_estimators=50 .................................................[CV] n_estimators=50 .................................................
#
# [CV] n_estimators=50 .................................................[CV] n_estimators=50 .................................................
# [CV] n_estimators=50 .................................................
# [CV] n_estimators=50 .................................................
# [CV] n_estimators=50 .................................................
# [CV] n_estimators=50 .................................................
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [CV] ..................... n_estimators=50, score=0.579, total=   9.4s
# [CV] n_estimators=50 .................................................
# [CV] ..................... n_estimators=50, score=0.640, total=   9.8s
# [CV] n_estimators=50 .................................................
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    9.7s
# [CV] ..................... n_estimators=50, score=0.640, total=  10.0s[CV] ..................... n_estimators=50, score=0.594, total=  10.0s
# [CV] ..................... n_estimators=50, score=0.600, total=  10.0s
#
# [CV] n_estimators=100 ................................................
# [CV] n_estimators=100 ................................................
# [CV] n_estimators=100 ................................................
# [CV] ..................... n_estimators=50, score=0.610, total=  10.3s
# [CV] n_estimators=100 ................................................
# [CV] ..................... n_estimators=50, score=0.670, total=  12.4s
# [CV] n_estimators=100 ................................................
# [CV] ..................... n_estimators=50, score=0.599, total=  13.2s
# [CV] n_estimators=100 ................................................
# [CV] ..................... n_estimators=50, score=0.520, total=   9.0s
# [CV] n_estimators=100 ................................................
# [CV] ..................... n_estimators=50, score=0.520, total=   9.1s
# [CV] n_estimators=100 ................................................
# [CV] .................... n_estimators=100, score=0.620, total=  17.4s
# [CV] n_estimators=100 ................................................
# [CV] .................... n_estimators=100, score=0.579, total=  18.0s
# [CV] n_estimators=100 ................................................
# [CV] .................... n_estimators=100, score=0.540, total=  17.8s
# [CV] n_estimators=250 ................................................
# [CV] .................... n_estimators=100, score=0.588, total=  18.9s
# [CV] n_estimators=250 ................................................
# [CV] .................... n_estimators=100, score=0.569, total=  17.4s
# [CV] n_estimators=250 ................................................
# [CV] .................... n_estimators=100, score=0.620, total=  20.2s
# [CV] n_estimators=250 ................................................
# [CV] .................... n_estimators=100, score=0.548, total=  17.3s
# [CV] n_estimators=250 ................................................
# [CV] .................... n_estimators=100, score=0.669, total=  17.7s
# [CV] n_estimators=250 ................................................
# [CV] .................... n_estimators=100, score=0.559, total=  17.1s
# [CV] n_estimators=250 ................................................
# [CV] .................... n_estimators=100, score=0.550, total=  17.7s
# [CV] n_estimators=250 ................................................
# [CV] .................... n_estimators=250, score=0.619, total=  40.9s
# [CV] n_estimators=250 ................................................
# [CV] .................... n_estimators=250, score=0.580, total=  42.3s
# [CV] n_estimators=250 ................................................
# [CV] .................... n_estimators=250, score=0.599, total=  41.3s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=250, score=0.580, total=  42.6s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=250, score=0.619, total=  40.9s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=250, score=0.559, total=  42.3s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=250, score=0.570, total=  42.5s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=250, score=0.710, total=  41.6s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=250, score=0.540, total=  40.8s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=250, score=0.568, total=  42.0s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=500, score=0.580, total= 1.3min
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=500, score=0.620, total= 1.3min
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=500, score=0.596, total= 1.3min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=500, score=0.609, total= 1.3min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=500, score=0.638, total= 1.3min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=500, score=0.550, total= 1.3min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=500, score=0.590, total= 1.3min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=500, score=0.710, total= 1.3min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=500, score=0.559, total= 1.3min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=500, score=0.570, total= 1.5min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=750, score=0.600, total= 1.9min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=750, score=0.580, total= 1.9min
# [CV] n_estimators=750 ................................................
# [CV] .................... n_estimators=750, score=0.557, total= 1.9min
# [CV] n_estimators=1000 ...............................................
# [CV] .................... n_estimators=750, score=0.599, total= 1.9min
# [CV] n_estimators=1000 ...............................................
# [CV] .................... n_estimators=750, score=0.608, total= 1.9min
# [CV] n_estimators=1000 ...............................................
# [CV] .................... n_estimators=750, score=0.549, total= 1.9min
# [CV] n_estimators=1000 ...............................................
# [CV] .................... n_estimators=750, score=0.600, total= 1.9min
# [CV] n_estimators=1000 ...............................................
# [CV] .................... n_estimators=750, score=0.740, total= 2.0min
# [CV] n_estimators=1000 ...............................................
# [CV] .................... n_estimators=750, score=0.579, total= 2.0min
# [CV] n_estimators=1000 ...............................................
# [CV] .................... n_estimators=750, score=0.610, total= 2.1min
# [CV] n_estimators=1000 ...............................................
# [CV] ................... n_estimators=1000, score=0.580, total= 2.5min
# [CV] n_estimators=1000 ...............................................
# [CV] ................... n_estimators=1000, score=0.580, total= 2.5min
# [CV] n_estimators=1000 ...............................................
# [CV] ................... n_estimators=1000, score=0.556, total= 2.5min
# [CV] ................... n_estimators=1000, score=0.620, total= 2.5min
# [CV] ................... n_estimators=1000, score=0.608, total= 2.3min
# [CV] ................... n_estimators=1000, score=0.544, total= 2.3min
# [CV] ................... n_estimators=1000, score=0.609, total= 2.1min
# [CV] ................... n_estimators=1000, score=0.749, total= 2.1min
# [Parallel(n_jobs=-1)]: Done  58 out of  60 | elapsed:  8.7min remaining:   17.9s
# [CV] ................... n_estimators=1000, score=0.590, total= 1.8min
# [CV] ................... n_estimators=1000, score=0.559, total= 1.9min
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  9.0min finished
# Best: 0.602203 using {'n_estimators': 750}
# 0.597229 (0.046247) with: {'n_estimators': 50}
# 0.584208 (0.038926) with: {'n_estimators': 100}
# 0.594390 (0.045245) with: {'n_estimators': 250}
# 0.602115 (0.044203) with: {'n_estimators': 500}
# 0.602203 (0.049957) with: {'n_estimators': 750}
# 0.599529 (0.055208) with: {'n_estimators': 1000}
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.57      0.55       357
#          1.0       0.67      0.63      0.65       489
#
#     accuracy                           0.60       846
#    macro avg       0.60      0.60      0.60       846
# weighted avg       0.61      0.60      0.61       846
#
# Test accuracy: 0.6040189125295509

# %% [markdown]
# ### Neural Network

# %%
def create_model(nodes=100, depth=2, dropout_rate=0.3, optimizer='rmsprop'):
    model = Sequential() 
    if depth == 1: 
        model.add(Dense(1, input_shape=x_train_1yr.shape[1:], activation='sigmoid'))
        model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['acc'])
        return model 
    model.add(Dense(nodes, input_shape=x_train_1yr.shape[1:]))
    model.add(Dropout(dropout_rate))
    for i in range(depth - 2):
        model.add(Dense(nodes))
        model.add(Dropout(dropout_rate))
    model.add(Dense(1, activation='sigmoid'))
    
    model.compile(optimizer=optimizer,loss='binary_crossentropy',metrics=['acc'])
    return model 

earlystop = EarlyStopping(monitor='val_loss',
                          patience=3,
                          restore_best_weights=True)

# %% [markdown]
# #### 1 year rate

# %%
# Perform a cross-validation to find good values of hyperparameters

model_1yr = KerasClassifier(build_fn=create_model, verbose=0)
# define the grid search parameters
batch_size = [8, 16, 32]
epochs = [4,5,6]
nodes = [50,100, 250, 500]
depth = [1,2,3]
dropout_rates = [0.2, 0.3, 0.4, 0.5]
optimizers = ['RMSprop','Adam']
nn_param_grid = dict(batch_size=batch_size,
                     epochs=epochs,
                     nodes=nodes,
                     dropout_rate=dropout_rates,
                     depth=depth,
                     optimizer=optimizers)
nn_grid = GridSearchCV(estimator=model_1yr,
                       param_grid=nn_param_grid,
                       n_jobs=-1,
                       cv=3,
                       scoring='f1_weighted',
                       verbose=10)
with parallel_backend('threading'):    # This is a bug work-around mentioned in https://github.com/scikit-learn/scikit-learn/issues/12546
    nn_grid_result = nn_grid.fit(x_train_1yr.todense(), y_train_1yr)
# summarize results
print("Best: %f using %s" % (nn_grid_result.best_score_, nn_grid_result.best_params_))
means = nn_grid_result.cv_results_['mean_test_score']
stds = nn_grid_result.cv_results_['std_test_score']
params = nn_grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
    
model_1yr = create_model(nodes=nn_grid_result.best_params_['nodes'],
                     depth=nn_grid_result.best_params_['depth'],
                     dropout_rate=nn_grid_result.best_params_['dropout_rate'])

history_1yr = model_1yr.fit(x_train_1yr.todense(), y_train_1yr,
                    validation_split=0.2,
                    epochs=20,
                    batch_size=nn_grid_result.best_params_['batch_size'],
                    callbacks=[earlystop],
                    verbose=1)

plot_results_nn(history_1yr,
                model_1yr,
                x_test_1yr,
                y_test_1yr,
                save=True,
                name='nn_1yr_n{}_de{}_dr{}'.format(nn_grid_result.best_params_['nodes'],
                                                                                    nn_grid_result.best_params_['depth'],
                                                                                    nn_grid_result.best_params_['dropout_rate']))
# Out:
# Fitting 3 folds for each of 864 candidates, totalling 2592 fits
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50, optimizer=RMSprop
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50, optimizer=RMSprop
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50, optimizer=RMSprop
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50, optimizer=Adam
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50, optimizer=Adam
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50, optimizer=Adam
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100, optimizer=RMSprop
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100, optimizer=RMSprop
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50, optimizer=Adam, score=0.513, total=   5.0s[CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50, optimizer=Adam, score=0.552, total=   5.0s
#
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100, optimizer=RMSprop [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100, optimizer=Adam
#
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100, optimizer=RMSprop, score=0.549, total=   5.1s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100, optimizer=RMSprop, score=0.559, total=   5.1s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50, optimizer=Adam, score=0.538, total=   5.1s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50, optimizer=RMSprop, score=0.530, total=   5.2s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250, optimizer=RMSprop
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    4.9s
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50, optimizer=RMSprop, score=0.561, total=   5.4s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250, optimizer=RMSprop
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# KeyError: 'metrics_412/acc/AssignAddVariableOp_1'
#
#   FitFailedWarning)
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100, optimizer=Adam, score=nan, total=   0.6s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50, optimizer=RMSprop, score=0.528, total=   6.6s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250, optimizer=Adam
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    6.5s
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100, optimizer=Adam, score=0.538, total=   5.2s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100, optimizer=RMSprop, score=0.534, total=   5.4s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=500, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100, optimizer=Adam, score=0.526, total=   5.4s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=500, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250, optimizer=RMSprop, score=0.532, total=   5.5s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=500, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250, optimizer=RMSprop, score=0.534, total=   5.5s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=500, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250, optimizer=Adam, score=0.533, total=   5.6s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=500, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250, optimizer=RMSprop, score=0.541, total=   7.2s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=500, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes
0s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=50, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=250, optimizer=Adam, score=0.529, total=   5.8s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=50, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=500, optimizer=RMSprop, score=0.548, total=   6.1s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=50, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=500, optimizer=RMSprop, score=0.519, total=   6.1s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=50, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=500, optimizer=Adam, score=0.533, total=   5.6s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=50, optimizer=Adam
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:   52.7s
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=500, optimizer=RMSprop, score=0.576, total=   7.9s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=50, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=500, optimizer=Adam, score=0.546, total=   6.2s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=100, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=500, optimizer=Adam, score=0.522, total=   6.2s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=100, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=50, optimizer=RMSprop, score=0.536, total=   5.5s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=100, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=50, optimizer=RMSprop, score=0.534, total=   5.6s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=100, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=50, optimizer=Adam, score=0.543, total=   5.2s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=100, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=50, optimizer=RMSprop, score=0.556, total=   6.4s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=100, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=50, optimizer=Adam, score=0.536, total=   5.3s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=250, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=50, optimizer=Adam, score=0.511, total=   4.9s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=250, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=100, optimizer=RMSprop, score=0.533, total=   5.3s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=250, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=100, optimizer=RMSprop, score=0.546, total=   5.5s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=250, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=100, optimizer=Adam, score=0.547, total=   5.0s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=250, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=100, optimizer=Adam, score=0.530, total=   5.0s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=250, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=100, optimizer=RMSprop, score=0.542, total=   6.5s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=500, optimizer=RMSprop
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:  1.0min
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=100, optimizer=Adam, score=0.515, total=   5.1s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=500, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=250, optimizer=RMSprop, score=0.525, total=   5.2s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=500, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=250, optimizer=RMSprop, score=0.549, total=   5.5s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=500, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=250, optimizer=RMSprop, score=0.534, total=   5.5s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=500, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=250, optimizer=Adam, score=0.543, total=   5.2s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=500, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=250, optimizer=Adam, score=0.543, total=   5.1s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=50, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=500, optimizer=RMSprop, score=0.536, total=   5.3s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=50, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=500, optimizer=RMSprop, score=0.543, total=   5.3s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=50, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=500, optimizer=RMSprop, score=0.518, total=   5.3s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=50, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=250, optimizer=Adam, score=0.525, total=   6.2s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=50, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=500, optimizer=Adam, score=0.526, total=   5.3s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=50, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=500, optimizer=Adam, score=0.555, total=   5.0s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=100, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=500, optimizer=Adam, score=0.512, total=   5.0s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=100, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=50, optimizer=RMSprop, score=0.562, total=   5.7s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=100, optimizer=RMSprop
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:  1.2min
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=50, optimizer=RMSprop, score=0.549, total=   5.8s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=100, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=50, optimizer=RMSprop, score=0.531, total=   5.6s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=100, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=50, optimizer=Adam, score=0.551, total=   5.5s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=100, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=50, optimizer=Adam, score=0.555, total=   5.6s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=250, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=50, optimizer=Adam, score=0.555, total=   6.8s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=250, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=100, optimizer=RMSprop, score=0.526, total=   5.9s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=250, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=100, optimizer=RMSprop, score=0.558, total=   6.0s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=250, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=100, optimizer=RMSprop, score=0.525, total=   5.6s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=250, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=100, optimizer=Adam, score=0.540, total=   5.2s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=250, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=100, optimizer=Adam, score=0.513, total=   5.2s[CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=100, optimizer=Adam, score=0.554, total=   5.3s
#
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=500, optimizer=RMSprop
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=500, optimizer=RMSprop
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# KeyError: 'loss_307/dense_14_loss/mul_1'
#
#   FitFailedWarning)
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=250, optimizer=Adam, score=nan, total=   0.9s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=500, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=250, optimizer=RMSprop, score=0.557, total=   5.7s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=500, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=250, optimizer=RMSprop, score=0.558, total=   5.8s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=500, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes=250, optimizer=Adam, score=0.525, total=   5.8s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=5, nodes
optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.4, epochs=6, nodes=250, optimizer=Adam, score=0.538, total=   7.3s
# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=50, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.4, epochs=6, nodes=500, optimizer=Adam, score=0.542, total=   6.5s
# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=50, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.4, epochs=6, nodes=500, optimizer=Adam, score=0.562, total=   6.3s
# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=100, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=50, optimizer=RMSprop, score=0.556, total=   5.3s
# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=100, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.4, epochs=6, nodes=500, optimizer=Adam, score=0.525, total=   5.7s
# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=100, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=50, optimizer=RMSprop, score=0.540, total=   5.5s
# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=100, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=50, optimizer=Adam, score=0.512, total=   5.7s
# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=100, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=50, optimizer=Adam, score=0.539, total=   5.5s
# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=100, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=50, optimizer=RMSprop, score=0.502, total=   7.2s
# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=250, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=50, optimizer=Adam, score=0.508, total=   5.8s
# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=250, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=100, optimizer=RMSprop, score=0.526, total=   5.9s
# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=250, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=100, optimizer=RMSprop, score=0.530, total=   5.5s
# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=250, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=100, optimizer=Adam, score=0.545, total=   5.3s
# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=250, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=100, optimizer=RMSprop, score=0.530, total=   5.4s
# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=250, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=100, optimizer=Adam, score=0.534, total=   5.0s
# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=500, optimizer=RMSprop
# [Parallel(n_jobs=-1)]: Done 226 tasks      | elapsed:  2.8min
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=100, optimizer=Adam, score=0.520, total=   5.1s
# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=500, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=250, optimizer=RMSprop, score=0.563, total=   5.7s
# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=500, optimizer=RMSprop
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=250, optimizer=RMSprop, score=0.534, total=   5.7s
# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=500, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=250, optimizer=RMSprop, score=0.543, total=   5.8s
# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=500, optimizer=Adam
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=4, nodes=250, optimizer=Adam, score=0.508, total=   5.2s
# ...
# nan (nan) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 100, 'optimizer': 'Adam'}
# 0.500084 (0.004464) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 250, 'optimizer': 'RMSprop'}
# nan (nan) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 250, 'optimizer': 'Adam'}
# 0.496093 (0.024495) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 500, 'optimizer': 'RMSprop'}
# 0.498347 (0.025897) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 500, 'optimizer': 'Adam'}
# 0.484239 (0.002792) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 50, 'optimizer': 'RMSprop'}
# 0.509212 (0.011927) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 50, 'optimizer': 'Adam'}
# 0.497059 (0.033203) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 100, 'optimizer': 'RMSprop'}
# 0.490769 (0.022424) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 100, 'optimizer': 'Adam'}
# 0.490648 (0.018199) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 250, 'optimizer': 'RMSprop'}
# 0.479844 (0.024377) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 250, 'optimizer': 'Adam'}
# 0.471869 (0.020980) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 500, 'optimizer': 'RMSprop'}
# 0.479282 (0.029263) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 500, 'optimizer': 'Adam'}
# 0.504725 (0.026301) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 50, 'optimizer': 'RMSprop'}
# 0.491657 (0.019728) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 50, 'optimizer': 'Adam'}
# 0.491275 (0.021829) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 100, 'optimizer': 'RMSprop'}
# 0.499017 (0.024174) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 100, 'optimizer': 'Adam'}
# 0.492709 (0.029246) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 250, 'optimizer': 'RMSprop'}
# 0.484731 (0.022992) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 250, 'optimizer': 'Adam'}
# 0.504539 (0.010750) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 500, 'optimizer': 'RMSprop'}
# 0.482983 (0.022676) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 500, 'optimizer': 'Adam'}
# 0.494688 (0.026623) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 50, 'optimizer': 'RMSprop'}
# 0.495677 (0.019882) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 50, 'optimizer': 'Adam'}
# 0.493010 (0.017364) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 100, 'optimizer': 'RMSprop'}
# 0.488851 (0.015766) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 100, 'optimizer': 'Adam'}
# 0.481679 (0.016259) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 250, 'optimizer': 'RMSprop'}
# nan (nan) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 250, 'optimizer': 'Adam'}
# 0.486722 (0.024929) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 500, 'optimizer': 'RMSprop'}
# 0.473573 (0.032347) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 500, 'optimizer': 'Adam'}
# 0.505872 (0.023341) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 50, 'optimizer': 'RMSprop'}
# 0.513820 (0.015392) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 50, 'optimizer': 'Adam'}
# 0.484215 (0.011700) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 100, 'optimizer': 'RMSprop'}
# 0.475574 (0.023127) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 100, 'optimizer': 'Adam'}
# 0.498833 (0.026592) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 250, 'optimizer': 'RMSprop'}
# 0.492938 (0.025100) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 250, 'optimizer': 'Adam'}
# 0.486981 (0.021333) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 500, 'optimizer': 'RMSprop'}
# 0.483132 (0.040152) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 500, 'optimizer': 'Adam'}
# 0.514222 (0.027091) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 50, 'optimizer': 'RMSprop'}
# nan (nan) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 50, 'optimizer': 'Adam'}
# 0.488220 (0.032070) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 100, 'optimizer': 'RMSprop'}
# 0.492857 (0.021696) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 100, 'optimizer': 'Adam'}
# 0.498268 (0.019730) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 250, 'optimizer': 'RMSprop'}
# 0.489278 (0.025612) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 250, 'optimizer': 'Adam'}
# 0.484717 (0.031310) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 500, 'optimizer': 'RMSprop'}
# 0.468830 (0.018938) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 500, 'optimizer': 'Adam'}
# 0.500181 (0.019763) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 50, 'optimizer': 'RMSprop'}
# 0.491625 (0.016945) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 50, 'optimizer': 'Adam'}
# 0.499258 (0.032782) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 100, 'optimizer': 'RMSprop'}
# 0.496947 (0.010669) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 100, 'optimizer': 'Adam'}
# 0.482609 (0.021831) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 250, 'optimizer': 'RMSprop'}
# 0.484978 (0.030525) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 250, 'optimizer': 'Adam'}
# 0.496726 (0.012483) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 500, 'optimizer': 'RMSprop'}
# 0.480949 (0.021837) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 500, 'optimizer': 'Adam'}
# 0.530170 (0.017692) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 50, 'optimizer': 'RMSprop'}
# 0.510142 (0.022322) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 50, 'optimizer': 'Adam'}
# 0.466383 (0.014230) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 100, 'optimizer': 'RMSprop'}
# 0.498157 (0.013271) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 100, 'optimizer': 'Adam'}
# 0.478981 (0.032091) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 250, 'optimizer': 'RMSprop'}
# 0.478743 (0.022581) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 250, 'optimizer': 'Adam'}
# 0.488032 (0.028526) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 500, 'optimizer': 'RMSprop'}
# 0.479946 (0.011881) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 500, 'optimizer': 'Adam'}
# 0.507587 (0.013461) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 50, 'optimizer': 'RMSprop'}
# 0.496488 (0.009141) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 50, 'optimizer': 'Adam'}
# 0.498029 (0.035505) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 100, 'optimizer': 'RMSprop'}
# 0.482675 (0.028172) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 100, 'optimizer': 'Adam'}
# 0.488301 (0.020174) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 250, 'optimizer': 'RMSprop'}
# 0.487842 (0.031849) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 250, 'optimizer': 'Adam'}
# 0.488954 (0.021603) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 500, 'optimizer': 'RMSprop'}
# 0.475618 (0.019724) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 500, 'optimizer': 'Adam'}
# 0.487834 (0.015840) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 50, 'optimizer': 'RMSprop'}
# 0.492777 (0.016449) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 50, 'optimizer': 'Adam'}
# 0.491473 (0.016903) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 100, 'optimizer': 'RMSprop'}
# 0.487709 (0.026620) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 100, 'optimizer': 'Adam'}
# 0.499008 (0.021548) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 250, 'optimizer': 'RMSprop'}
# 0.478958 (0.021652) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 250, 'optimizer': 'Adam'}
# 0.488653 (0.022568) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 500, 'optimizer': 'RMSprop'}
# 0.473820 (0.022324) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 500, 'optimizer': 'Adam'}
# 0.535473 (0.005623) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 50, 'optimizer': 'RMSprop'}
# 0.527915 (0.019363) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 50, 'optimizer': 'Adam'}
# 0.514713 (0.014524) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 100, 'optimizer': 'RMSprop'}
# 0.488733 (0.015407) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 100, 'optimizer': 'Adam'}
# 0.487681 (0.022447) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 250, 'optimizer': 'RMSprop'}
# 0.474809 (0.021997) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 250, 'optimizer': 'Adam'}
# 0.480809 (0.021297) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 500, 'optimizer': 'RMSprop'}
# 0.492568 (0.035900) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 500, 'optimizer': 'Adam'}
# 0.514813 (0.016967) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 50, 'optimizer': 'RMSprop'}
# 0.500974 (0.010538) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 50, 'optimizer': 'Adam'}
# 0.483123 (0.011238) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 100, 'optimizer': 'RMSprop'}
# 0.486625 (0.014641) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 100, 'optimizer': 'Adam'}
# 0.482935 (0.029619) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 250, 'optimizer': 'RMSprop'}
# 0.492912 (0.023246) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 250, 'optimizer': 'Adam'}
# 0.491138 (0.021665) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 500, 'optimizer': 'RMSprop'}
# 0.483285 (0.016324) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 500, 'optimizer': 'Adam'}
# 0.512746 (0.012461) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 50, 'optimizer': 'RMSprop'}
# 0.500428 (0.032346) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 50, 'optimizer': 'Adam'}
# 0.495395 (0.025686) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 100, 'optimizer': 'RMSprop'}
# 0.487866 (0.021851) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 100, 'optimizer': 'Adam'}
# 0.497407 (0.007926) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 250, 'optimizer': 'RMSprop'}
# 0.498953 (0.031431) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 250, 'optimizer': 'Adam'}
# 0.487925 (0.020295) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 500, 'optimizer': 'RMSprop'}
# 0.478610 (0.031022) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 500, 'optimizer': 'Adam'}
# Train on 800 samples, validate on 200 samples
# Epoch 1/20
# 800/800 [==============================] - 1s 877us/sample - loss: 0.6932 - acc: 0.5000 - val_loss: 0.6923 - val_acc: 0.5500
# Epoch 2/20
# 800/800 [==============================] - 0s 337us/sample - loss: 0.6829 - acc: 0.6888 - val_loss: 0.6918 - val_acc: 0.5550
# Epoch 3/20
# 800/800 [==============================] - 0s 356us/sample - loss: 0.6733 - acc: 0.7663 - val_loss: 0.6912 - val_acc: 0.5550
# Epoch 4/20
# 800/800 [==============================] - 0s 356us/sample - loss: 0.6639 - acc: 0.8100 - val_loss: 0.6906 - val_acc: 0.5850
# Epoch 5/20
# 800/800 [==============================] - 0s 356us/sample - loss: 0.6547 - acc: 0.8350 - val_loss: 0.6903 - val_acc: 0.5800
# Epoch 6/20
# 800/800 [==============================] - 0s 376us/sample - loss: 0.6457 - acc: 0.8388 - val_loss: 0.6899 - val_acc: 0.5900
# Epoch 7/20
# 800/800 [==============================] - 0s 357us/sample - loss: 0.6370 - acc: 0.8438 - val_loss: 0.6890 - val_acc: 0.5850
# Epoch 8/20
# 800/800 [==============================] - 0s 366us/sample - loss: 0.6283 - acc: 0.8550 - val_loss: 0.6885 - val_acc: 0.5750
# Epoch 9/20
# 800/800 [==============================] - 0s 357us/sample - loss: 0.6198 - acc: 0.8650 - val_loss: 0.6882 - val_acc: 0.5700
# Epoch 10/20
# 800/800 [==============================] - 0s 355us/sample - loss: 0.6116 - acc: 0.8750 - val_loss: 0.6878 - val_acc: 0.5600
# Epoch 11/20
# 800/800 [==============================] - 0s 356us/sample - loss: 0.6035 - acc: 0.8788 - val_loss: 0.6877 - val_acc: 0.5600
# Epoch 12/20
# 800/800 [==============================] - 0s 356us/sample - loss: 0.5955 - acc: 0.8888 - val_loss: 0.6874 - val_acc: 0.5450
# Epoch 13/20
# 800/800 [==============================] - 0s 356us/sample - loss: 0.5876 - acc: 0.8900 - val_loss: 0.6872 - val_acc: 0.5500
# Epoch 14/20
# 800/800 [==============================] - 0s 362us/sample - loss: 0.5799 - acc: 0.8925 - val_loss: 0.6874 - val_acc: 0.5500
# Epoch 15/20
# 800/800 [==============================] - 0s 342us/sample - loss: 0.5723 - acc: 0.9000 - val_loss: 0.6872 - val_acc: 0.5550
# Epoch 16/20
# 800/800 [==============================] - 0s 362us/sample - loss: 0.5649 - acc: 0.9000 - val_loss: 0.6868 - val_acc: 0.5600
# Epoch 17/20
# 800/800 [==============================] - 0s 350us/sample - loss: 0.5576 - acc: 0.9137 - val_loss: 0.6867 - val_acc: 0.5600
# Epoch 18/20
# 800/800 [==============================] - 0s 360us/sample - loss: 0.5503 - acc: 0.9212 - val_loss: 0.6870 - val_acc: 0.5550
# Epoch 19/20
# 800/800 [==============================] - 0s 353us/sample - loss: 0.5433 - acc: 0.9200 - val_loss: 0.6873 - val_acc: 0.5600
# Epoch 20/20
# 800/800 [==============================] - 0s 368us/sample - loss: 0.5363 - acc: 0.9275 - val_loss: 0.6874 - val_acc: 0.5600
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.56      0.70       771
#          1.0       0.11      0.53      0.18        75
#
#     accuracy                           0.56       846
#    macro avg       0.52      0.55      0.44       846
# weighted avg       0.85      0.56      0.65       846
#
# Test accuracy: 0.557

# %% [markdown]
# #### 3 year rate

# %%
# Perform a cross-validation to find good values of hyperparameters

model_3yr = KerasClassifier(build_fn=create_model, verbose=0)
# define the grid search parameters
batch_size = [8, 16, 32]
epochs = [4,5,6]
nodes = [50,100, 250, 500]
depth = [1,2,3]
dropout_rates = [0.2, 0.3, 0.4, 0.5]
optimizers = ['RMSprop','Adam']
nn_param_grid = dict(batch_size=batch_size, epochs=epochs, nodes=nodes, dropout_rate=dropout_rates, depth=depth)
nn_grid = GridSearchCV(estimator=model_3yr,
                       param_grid=nn_param_grid,
                       n_jobs=-1,
                       cv=5,
                       scoring='f1_weighted',
                       verbose=10)
with parallel_backend('threading'):    # This is a bug work-around mentioned in https://github.com/scikit-learn/scikit-learn/issues/12546
    nn_grid_result = nn_grid.fit(x_train_3yr.todense(), y_train_3yr)
# summarize results
print("Best: %f using %s" % (nn_grid_result.best_score_, nn_grid_result.best_params_))
means = nn_grid_result.cv_results_['mean_test_score']
stds = nn_grid_result.cv_results_['std_test_score']
params = nn_grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
    
model_3yr = create_model(nodes=nn_grid_result.best_params_['nodes'],
                     depth=nn_grid_result.best_params_['depth'],
                     dropout_rate=nn_grid_result.best_params_['dropout_rate'])

history_3yr = model_3yr.fit(x_train_3yr.todense(), y_train_3yr,
                            validation_split=0.2,
                            epochs=20,
                            batch_size=nn_grid_result.best_params_['batch_size'],
                            callbacks=[earlystop],
                            verbose=1)

plot_results_nn(history_3yr, 
                model_3yr,
                x_test_3yr,
                y_test_3yr,
                save=True,
                name='nn_3yr_n{}_de{}_dr{}'.format(nn_grid_result.best_params_['nodes'],
                                                   nn_grid_result.best_params_['depth'],
                                                   nn_grid_result.best_params_['dropout_rate']))
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50 .....[CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50 .....
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50 .....
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50 .....
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50 .....
#
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100 ....
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100 ....
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100 ....
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50, score=0.513, total=   9.0s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50, score=0.561, total=   9.1s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50, score=0.466, total=   9.1s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50, score=0.633, total=   9.2s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    9.0s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100, score=0.576, total=   9.3s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50, score=0.487, total=   9.3s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100, score=0.513, total=   9.4s[CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=50 .....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=250, score=0.554, total= 1.2min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=50 .....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=250, score=0.554, total= 1.2min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=50 .....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=500, score=0.511, total= 1.5min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=50 .....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=500, score=0.507, total= 1.5min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=50 .....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=500, score=0.564, total= 1.4min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=100 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=50, score=0.495, total=  58.1s
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=100 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=50, score=0.501, total=  54.2s
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=100 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=50, score=0.565, total=  51.4s
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=100 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=500, score=0.549, total= 1.3min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=100 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=500, score=0.534, total= 1.3min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=250 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=50, score=0.569, total=  47.1s
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=250 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=50, score=0.554, total=  44.4s
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=250 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=100, score=0.499, total=  49.8s
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=250 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=100, score=0.458, total=  49.3s
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=250 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=100, score=0.549, total=  52.5s
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=500 ....
# ...
# 0.522615 (0.044715) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 500}
# 0.511742 (0.056666) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 50}
# 0.522755 (0.031045) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 100}
# 0.509768 (0.056707) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 250}
# 0.506442 (0.051779) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 500}
# 0.515008 (0.037378) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 50}
# 0.516507 (0.044214) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 100}
# 0.521963 (0.059523) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 250}
# 0.529243 (0.053174) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 500}
# 0.499361 (0.066385) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 50}
# 0.512981 (0.045520) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 100}
# 0.498424 (0.040320) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 250}
# 0.512443 (0.049505) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 500}
# 0.499935 (0.037432) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 50}
# 0.505244 (0.052386) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 100}
# 0.498873 (0.051317) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 250}
# 0.515654 (0.065407) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 500}
# 0.517835 (0.049611) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 50}
# 0.518748 (0.028709) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 100}
# 0.527258 (0.053449) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 250}
# 0.538987 (0.045248) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 500}
# 0.504386 (0.066137) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 50}
# 0.513676 (0.049891) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 100}
# 0.507547 (0.058641) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 250}
# 0.506671 (0.054973) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 500}
# nan (nan) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 50}
# 0.511636 (0.041780) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 100}
# 0.533452 (0.046271) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 250}
# 0.512758 (0.052222) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 500}
# 0.516208 (0.040965) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 50}
# 0.515868 (0.040711) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 100}
# 0.517048 (0.053113) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 250}
# 0.516362 (0.045052) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 500}
# 0.513372 (0.048085) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 50}
# 0.499234 (0.042674) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 100}
# 0.508813 (0.043413) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 250}
# 0.513221 (0.052037) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 500}
# 0.506492 (0.063096) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 50}
# 0.492121 (0.048492) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 100}
# 0.514150 (0.055790) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 250}
# 0.519185 (0.067968) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 500}
# 0.504559 (0.043394) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 50}
# 0.520477 (0.019914) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 100}
# 0.501534 (0.040075) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 250}
# 0.514833 (0.061195) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 500}
# 0.524114 (0.040542) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 50}
# 0.522664 (0.027685) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 100}
# 0.540882 (0.040229) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 250}
# 0.525510 (0.024370) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 500}
# 0.540784 (0.028280) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 50}
# 0.522307 (0.035986) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 100}
# 0.535597 (0.019339) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 250}
# 0.530840 (0.027464) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 500}
# 0.534820 (0.020512) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 50}
# 0.545741 (0.029841) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 100}
# 0.528525 (0.024387) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 250}
# 0.545549 (0.024589) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 500}
# 0.546441 (0.025875) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 50}
# 0.545627 (0.031140) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 100}
# 0.535090 (0.037426) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 250}
# 0.529118 (0.039643) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 500}
# 0.535267 (0.020037) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 50}
# 0.542372 (0.028620) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 100}
# 0.514668 (0.052737) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 250}
# 0.528100 (0.025416) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 500}
# 0.546524 (0.023358) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 50}
# 0.533003 (0.033700) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 100}
# 0.533903 (0.018863) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 250}
# 0.528734 (0.018898) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 500}
# 0.530793 (0.041106) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 50}
# 0.540730 (0.027482) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 100}
# 0.523236 (0.024208) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 250}
# 0.525055 (0.022233) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 500}
# 0.546308 (0.039408) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 50}
# 0.538044 (0.050192) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 100}
# 0.537845 (0.032427) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 250}
# 0.531946 (0.036339) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 500}
# 0.531361 (0.011335) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 50}
# 0.530317 (0.015915) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 100}
# 0.543507 (0.017922) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 250}
# 0.530602 (0.022608) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 500}
# 0.544054 (0.030210) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 50}
# 0.548197 (0.034976) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 100}
# 0.531765 (0.034840) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 250}
# 0.531514 (0.019037) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 500}
# 0.536871 (0.033655) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 50}
# 0.540101 (0.027132) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 100}
# 0.530463 (0.022761) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 250}
# 0.536498 (0.028695) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 500}
# 0.542127 (0.022316) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 50}
# 0.554555 (0.029848) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 100}
# 0.522092 (0.043522) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 250}
# 0.533929 (0.028009) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 500}
# 0.534682 (0.036226) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 50}
# 0.530765 (0.027910) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 100}
# 0.509054 (0.028898) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 250}
# 0.529251 (0.031766) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 500}
# 0.532203 (0.019034) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 50}
# 0.544685 (0.028856) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 100}
# 0.547572 (0.017624) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 250}
# 0.522246 (0.028755) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 500}
# 0.527012 (0.027341) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 50}
# 0.536856 (0.026317) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 100}
# 0.529713 (0.027825) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 250}
# 0.516624 (0.032874) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 500}
# 0.523407 (0.044856) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 50}
# 0.533536 (0.033904) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 100}
# 0.520624 (0.032622) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 250}
# 0.527480 (0.034399) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 500}
# 0.544616 (0.021738) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 50}
# 0.530036 (0.034219) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 100}
# 0.536435 (0.032694) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 250}
# 0.532076 (0.028708) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 500}
# 0.530614 (0.020687) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 50}
# 0.520566 (0.044289) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 100}
# 0.538886 (0.026258) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 250}
# 0.533967 (0.033233) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 500}
# 0.530770 (0.032560) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 50}
# 0.525453 (0.027996) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 100}
# 0.532754 (0.024118) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 250}
# 0.543132 (0.034842) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 500}
# 0.539473 (0.023454) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 50}
# 0.537878 (0.016935) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 100}
# 0.522329 (0.024906) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 250}
# 0.537636 (0.023879) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 500}
# 0.537906 (0.036135) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 50}
# 0.524219 (0.027307) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 100}
# 0.532408 (0.026508) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 250}
# 0.533912 (0.022713) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 500}
# 0.549520 (0.032190) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 50}
# 0.532857 (0.026106) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 100}
# 0.513706 (0.028834) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 250}
# 0.517699 (0.059498) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 500}
# 0.531198 (0.028928) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 50}
# 0.524368 (0.041134) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 100}
# 0.530984 (0.043872) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 250}
# 0.543278 (0.026077) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 500}
# 0.530526 (0.027375) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 50}
# 0.537447 (0.023424) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 100}
# 0.529436 (0.015511) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 250}
# 0.523544 (0.035062) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 500}
# Train on 800 samples, validate on 200 samples
# Epoch 1/20
# 800/800 [==============================] - 3s 3ms/sample - loss: 0.6945 - acc: 0.4963 - val_loss: 0.6844 - val_acc: 0.5850
# Epoch 2/20
# 800/800 [==============================] - 2s 3ms/sample - loss: 0.6308 - acc: 0.7763 - val_loss: 0.6792 - val_acc: 0.5850
# Epoch 3/20
# 800/800 [==============================] - 2s 3ms/sample - loss: 0.5535 - acc: 0.8788 - val_loss: 0.6715 - val_acc: 0.5850
# Epoch 4/20
# 800/800 [==============================] - 2s 3ms/sample - loss: 0.4563 - acc: 0.9300 - val_loss: 0.6715 - val_acc: 0.5900
# Epoch 5/20
# 800/800 [==============================] - 2s 3ms/sample - loss: 0.3541 - acc: 0.9650 - val_loss: 0.6761 - val_acc: 0.5900
# Epoch 6/20
# 800/800 [==============================] - 2s 3ms/sample - loss: 0.2718 - acc: 0.9750 - val_loss: 0.6971 - val_acc: 0.5500
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.35      0.47       596
#          1.0       0.30      0.67      0.42       250
#
#     accuracy                           0.44       846
#    macro avg       0.51      0.51      0.44       846
# weighted avg       0.59      0.44      0.45       846
#
# Test accuracy: 0.444

# %% [markdown]
# #### S&P

# %%
# Perform a cross-validation to find good values of hyperparameters

model_sp = KerasClassifier(build_fn=create_model, verbose=0)
# define the grid search parameters
batch_size = [8, 16, 32]
epochs = [4,5,6]
nodes = [50,100, 250, 500]
depth = [1,2,3]
dropout_rates = [0.2, 0.3, 0.4, 0.5]
optimizers = ['RMSprop','Adam']
nn_param_grid = dict(batch_size=batch_size, epochs=epochs, nodes=nodes, dropout_rate=dropout_rates, depth=depth)
nn_grid = GridSearchCV(estimator=model_sp,
                       param_grid=nn_param_grid,
                       n_jobs=-1,
                       cv=5,
                       scoring='f1_weighted',
                       verbose=10)
with parallel_backend('threading'):    # This is a bug work-around mentioned in https://github.com/scikit-learn/scikit-learn/issues/12546
    nn_grid_result = nn_grid.fit(x_train_sp.todense(), y_train_sp)
# summarize results
print("Best: %f using %s" % (nn_grid_result.best_score_, nn_grid_result.best_params_))
means = nn_grid_result.cv_results_['mean_test_score']
stds = nn_grid_result.cv_results_['std_test_score']
params = nn_grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
    
model_sp = create_model(nodes=nn_grid_result.best_params_['nodes'],
                     depth=nn_grid_result.best_params_['depth'],
                     dropout_rate=nn_grid_result.best_params_['dropout_rate'])

history_sp = model_sp.fit(x_train_sp.todense(), y_train_sp,
                          validation_split=0.2,
                          epochs=20,
                          batch_size=nn_grid_result.best_params_['batch_size'],
                          callbacks=[earlystop],
                          verbose=1)

plot_results_nn(history_sp,
                model_sp,
                x_test_sp,
                y_test_sp,
                save=True,
                name='nn_sp_n{}_de{}_dr{}'.format(nn_grid_result.best_params_['nodes'],
                                                  nn_grid_result.best_params_['depth'],
                                                  nn_grid_result.best_params_['dropout_rate']))
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50 .....
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50 .....[CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50 .....
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50 .....
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50 .....
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100 ....
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100 ....
#
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100 ....
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100, score=0.551, total=  21.2s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50, score=0.573, total=  21.4s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100 ....
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   21.3s
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50, score=0.478, total=  21.5s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50, score=0.510, total=  21.6s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50, score=0.577, total=  21.7s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100, score=0.589, total=  21.7s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=50, score=0.516, total=  21.7s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100, score=0.464, total=  21.9s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=500 ....
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# KeyError: 'loss_4958/dense_1_loss/mul'
#
#   FitFailedWarning)
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   22.2s
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100, score=nan, total=   1.0s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=500 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250, score=0.544, total=  20.7s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=500 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=500, score=0.560, total=  20.4s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=500 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=100, score=0.490, total=  21.0s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=500 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250, score=0.544, total=  21.0s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=50 .....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250, score=0.477, total=  21.0s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=50 .....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250, score=0.546, total=  21.1s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=50 .....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=250, score=0.476, total=  21.1s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=50 .....
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   42.7s
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=500, score=0.542, total=  20.8s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=50 .....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=500, score=0.407, total=  20.9s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=100 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=500, score=0.467, total=  21.5s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=100 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=4, nodes=500, score=0.535, total=  21.7s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=100 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=50, score=0.535, total=  25.2s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=100 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=50, score=0.501, total=  25.5s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=100 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=50, score=0.585, total=  25.7s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=250 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=50, score=0.538, total=  25.7s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=250 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=50, score=0.480, total=  25.7s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=250 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=100, score=nan, total=   0.6s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=250 ....
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  1.1min
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# KeyError: 'loss_4978/dense_3_loss/Neg'
#
#   FitFailedWarning)
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=100, score=0.564, total=  21.9s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=250 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=100, score=0.453, total=  22.3s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=500 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=100, score=0.550, total=  22.6s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=500 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=100, score=0.535, total=  24.5s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=500 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=250, score=0.554, total=  25.1s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=500 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=250, score=0.593, total=  25.7s
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=250, score=0.499, total=  25.1s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=500 ....[CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=50 .....
#
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=250, score=0.518, total=  25.8s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=50 .....
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.6min
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=250, score=0.557, total=  24.5s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=50 .....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=500, score=0.564, total=  24.2s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=50 .....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=500, score=0.605, total=  24.5s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=50 .....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=500, score=0.449, total=  24.4s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=100 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=500, score=0.539, total=  24.2s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=100 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=5, nodes=500, score=0.508, total=  26.0s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=100 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=50, score=0.603, total=  30.3s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=100 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=50, score=0.551, total=  30.1s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=100 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=50, score=0.521, total=  28.4s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=250 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=50, score=0.539, total=  28.9s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=250 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=50, score=0.497, total=  29.1s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=250 ....
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:  2.3min
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=100, score=0.595, total=  28.1s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=250 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=100, score=0.555, total=  28.4s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=250 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=100, score=0.532, total=  28.7s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=500 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=100, score=0.556, total=  28.7s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=500 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=100, score=0.486, total=  29.2s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=500 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=250, score=0.570, total=  28.3s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=500 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=250, score=0.570, total=  28.5s
# [CV] batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=500 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=250, score=0.511, total=  28.7s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=50 .....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=250, score=0.498, total=  27.3s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=50 .....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=250, score=0.547, total=  29.0s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=50 .....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=500, score=0.605, total=  27.8s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=50 .....
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:  2.9min
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=500, score=0.446, total=  28.5s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=50 .....
# [CV]  batch_size=8, depth=1, dropout_rate=0.2, epochs=6, nodes=500, score=0.559, total=  29.3s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=100 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=50, score=0.604, total=  19.0s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=100 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=50, score=0.578, total=  19.7s
# [CV] batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes=100 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.3, epochs=4, nodes

# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=6, nodes=500 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=6, nodes=100, score=0.497, total=  26.9s
# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=6, nodes=500 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=6, nodes=250, score=0.619, total=  27.0s
# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=6, nodes=500 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=6, nodes=250, score=0.553, total=  29.0s
# [CV] batch_size=8, depth=1, dropout_rate=0.5, epochs=6, nodes=500 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=6, nodes=250, score=0.486, total=  29.2s
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=50 .....
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=6, nodes=250, score=0.544, total=  30.3s
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=50 .....
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=6, nodes=250, score=0.489, total=  34.9s
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=50 .....
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=6, nodes=500, score=0.598, total=  35.7s
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=50 .....
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=6, nodes=500, score=0.546, total=  35.1s
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=50 .....
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=6, nodes=500, score=0.458, total=  35.5s
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=100 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=6, nodes=500, score=0.533, total=  35.7s
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=100 ....
# [CV]  batch_size=8, depth=1, dropout_rate=0.5, epochs=6, nodes=500, score=0.508, total=  34.3s
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=100 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=50, score=0.583, total=  41.2s
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=100 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=50, score=0.600, total=  45.8s
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=100 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=50, score=0.569, total=  54.0s
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=250 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=50, score=0.550, total=  55.7s
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=250 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=50, score=0.530, total=  56.0s
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=250 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=100, score=0.595, total= 1.1min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=250 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=100, score=0.578, total= 1.1min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=250 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=100, score=0.558, total= 1.2min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=500 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=100, score=0.558, total= 1.3min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=500 ....
# [Parallel(n_jobs=-1)]: Done 249 tasks      | elapsed: 13.3min
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=100, score=0.540, total= 1.5min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=500 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=250, score=0.601, total= 2.2min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=500 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=250, score=0.573, total= 2.2min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=500 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=250, score=0.572, total= 2.1min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=50 .....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=250, score=0.524, total= 2.2min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=50 .....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=250, score=0.576, total= 2.3min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=50 .....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=500, score=0.575, total= 2.4min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=50 .....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=500, score=0.549, total= 2.4min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=50 .....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=500, score=0.576, total= 2.3min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=100 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=50, score=0.589, total= 1.6min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=100 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=50, score=0.535, total= 1.5min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=100 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=50, score=0.567, total= 1.5min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=100 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=500, score=0.548, total= 1.9min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=100 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=4, nodes=500, score=0.503, total= 1.9min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=250 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=50, score=0.592, total= 1.4min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=250 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=50, score=0.540, total= 1.4min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=250 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=100, score=0.594, total= 1.5min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=250 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=100, score=0.568, total= 1.7min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=250 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=100, score=0.574, total= 1.7min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=500 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=100, score=0.561, total= 1.7min
# [CV] batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=500 ....
# [CV]  batch_size=8, depth=2, dropout_rate=0.2, epochs=5, nodes=100, score=0.560, total= 1.7min
# ...
# 0.503967 (0.066273) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 50}
# 0.500623 (0.073827) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 100}
# 0.520547 (0.052104) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 250}
# 0.497068 (0.056225) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 500}
# 0.505141 (0.059199) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 50}
# 0.502096 (0.082284) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 100}
# 0.505567 (0.057826) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 250}
# 0.520282 (0.071551) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 500}
# 0.509847 (0.082570) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 50}
# 0.533099 (0.045116) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 100}
# 0.514168 (0.050262) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 250}
# 0.500084 (0.066666) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 500}
# 0.503108 (0.076920) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 50}
# 0.486895 (0.083361) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 100}
# 0.495492 (0.071061) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 250}
# 0.514550 (0.051647) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 500}
# 0.520724 (0.052400) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 50}
# 0.496248 (0.061993) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 100}
# 0.509074 (0.080887) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 250}
# 0.518355 (0.072923) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 500}
# 0.494209 (0.058247) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 50}
# 0.516985 (0.060193) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 100}
# 0.496782 (0.051642) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 250}
# 0.521809 (0.035897) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 500}
# 0.486271 (0.080704) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 50}
# 0.501533 (0.089373) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 100}
# 0.505270 (0.083964) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 250}
# nan (nan) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 500}
# 0.493835 (0.050165) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 50}
# 0.503098 (0.066803) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 100}
# 0.513699 (0.063517) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 250}
# 0.522902 (0.024400) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 500}
# 0.512890 (0.065422) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 50}
# 0.512647 (0.056280) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 100}
# 0.522508 (0.065558) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 250}
# 0.511867 (0.061319) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 500}
# 0.525880 (0.057179) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 50}
# 0.493413 (0.089346) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 100}
# 0.500523 (0.076089) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 250}
# nan (nan) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 500}
# 0.506616 (0.058187) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 50}
# nan (nan) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 100}
# 0.496026 (0.070075) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 250}
# 0.507148 (0.066564) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 500}
# 0.522763 (0.058346) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 50}
# 0.523272 (0.070068) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 100}
# 0.507182 (0.080747) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 250}
# 0.514060 (0.050735) with: {'batch_size': 32, 'depth': 1, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 500}
# 0.557372 (0.028518) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 50}
# 0.541892 (0.032721) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 100}
# nan (nan) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 250}
# 0.568626 (0.018170) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 500}
# 0.574605 (0.024186) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 50}
# 0.556403 (0.024916) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 100}
# nan (nan) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 250}
# 0.579700 (0.017227) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 500}
# 0.559996 (0.028577) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 50}
# 0.569291 (0.017476) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 100}
# 0.568051 (0.019283) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 250}
# 0.566350 (0.017918) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 500}
# 0.579289 (0.021987) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 50}
# 0.557957 (0.030726) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 100}
# 0.561255 (0.026601) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 250}
# 0.569271 (0.012953) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 500}
# 0.563697 (0.024140) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 50}
# 0.570964 (0.024795) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 100}
# 0.566759 (0.018376) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 250}
# 0.572513 (0.016524) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 500}
# 0.561104 (0.028019) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 50}
# 0.567402 (0.034911) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 100}
# 0.575571 (0.020777) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 250}
# 0.572685 (0.020392) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 500}
# 0.564726 (0.027198) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 50}
# 0.551388 (0.028309) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 100}
# 0.572707 (0.020141) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 250}
# 0.545297 (0.012609) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 500}
# 0.540076 (0.030291) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 50}
# 0.549542 (0.031540) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 100}
# 0.575046 (0.010268) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 250}
# 0.553147 (0.035337) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 500}
# 0.566258 (0.030299) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 50}
# 0.559914 (0.019088) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 100}
# 0.571686 (0.027955) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 250}
# 0.578736 (0.007299) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 500}
# 0.550905 (0.034405) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 50}
# 0.566860 (0.012247) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 100}
# 0.557313 (0.026657) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 250}
# 0.564908 (0.037022) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 500}
# 0.557650 (0.023319) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 50}
# 0.559868 (0.034761) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 100}
# 0.583723 (0.012463) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 250}
# 0.561534 (0.010922) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 500}
# 0.560766 (0.013666) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 50}
# 0.564159 (0.025509) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 100}
# 0.560638 (0.017028) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 250}
# 0.568387 (0.019159) with: {'batch_size': 32, 'depth': 2, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 500}
# 0.546837 (0.061726) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 50}
# 0.570960 (0.025528) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 100}
# 0.572765 (0.019567) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 250}
# 0.579953 (0.025835) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 4, 'nodes': 500}
# 0.576100 (0.017426) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 50}
# 0.569108 (0.019257) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 100}
# 0.577115 (0.024514) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 250}
# 0.575341 (0.020440) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 5, 'nodes': 500}
# 0.574274 (0.009023) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 50}
# 0.577552 (0.023853) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 100}
# 0.573038 (0.011708) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 250}
# 0.570950 (0.024877) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.2, 'epochs': 6, 'nodes': 500}
# 0.561780 (0.029013) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 50}
# 0.563049 (0.019749) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 100}
# 0.570316 (0.014469) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 250}
# 0.567415 (0.011152) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 4, 'nodes': 500}
# 0.570791 (0.018944) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 50}
# 0.570192 (0.012196) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 100}
# 0.570587 (0.020372) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 250}
# 0.574870 (0.017837) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 5, 'nodes': 500}
# 0.569366 (0.019092) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 50}
# 0.578678 (0.019674) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 100}
# 0.586085 (0.009645) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 250}
# 0.574544 (0.019267) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.3, 'epochs': 6, 'nodes': 500}
# 0.561209 (0.021269) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 50}
# 0.557808 (0.023334) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 100}
# 0.553497 (0.016794) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 250}
# 0.556806 (0.025908) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 4, 'nodes': 500}
# 0.569548 (0.017973) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 50}
# 0.565902 (0.016250) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 100}
# 0.573362 (0.023727) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 250}
# 0.575701 (0.018197) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 5, 'nodes': 500}
# 0.570858 (0.009634) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 50}
# 0.559485 (0.022720) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 100}
# 0.577846 (0.012824) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 250}
# 0.581453 (0.032361) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.4, 'epochs': 6, 'nodes': 500}
# 0.559989 (0.015778) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 50}
# 0.569000 (0.020339) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 100}
# 0.548200 (0.031143) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 250}
# 0.566460 (0.021961) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 4, 'nodes': 500}
# 0.570617 (0.008210) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 50}
# 0.570129 (0.019285) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 100}
# 0.570820 (0.019919) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 250}
# 0.575918 (0.013773) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 5, 'nodes': 500}
# 0.572969 (0.017529) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 50}
# 0.574983 (0.019606) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 100}
# 0.542685 (0.037355) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 250}
# 0.569794 (0.023380) with: {'batch_size': 32, 'depth': 3, 'dropout_rate': 0.5, 'epochs': 6, 'nodes': 500}
# Train on 800 samples, validate on 200 samples
# Epoch 1/20
# 800/800 [==============================] - 4s 6ms/sample - loss: 0.6959 - acc: 0.5038 - val_loss: 0.6950 - val_acc: 0.4800
# Epoch 2/20
# 800/800 [==============================] - 4s 5ms/sample - loss: 0.4543 - acc: 0.8763 - val_loss: 0.7197 - val_acc: 0.5550
# Epoch 3/20
# 800/800 [==============================] - 4s 5ms/sample - loss: 0.1018 - acc: 0.9887 - val_loss: 1.0446 - val_acc: 0.5150
# Epoch 4/20
# 800/800 [==============================] - 4s 5ms/sample - loss: 0.0110 - acc: 1.0000 - val_loss: 1.0389 - val_acc: 0.5450
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.82      0.56       357
#          1.0       0.62      0.21      0.32       489
#
#     accuracy                           0.47       846
#    macro avg       0.52      0.52      0.44       846
# weighted avg       0.54      0.47      0.42       846
#
# Test accuracy: 0.468

# %% [markdown]
# ## Results
#
# The following results were achieved on the independent test set on the 1 year rate, 3 year rate and S&P-500 index. Note that only the 10000 most common words were included in the vocabulary, to reduce the dimensionality.
# ### <center> 1 year rate </center>
# |               Model          |  Test Accuracy (%)  | Test weighted f1-score | Hyperparameters |
# | :--------------------------- | ------------------- | ---------------------: | --------------- |
# | Random Classifier            |          62         |          0.487         |       N/A       |
# | Logistic Regression          |          54         |          0.64          |       N/A       |
# | Support Vector Machine       |         52.4        |          0.62          |       N/A       |
# | Random Forest                |         0.00        |                        |n_estimators=3000, max_depth=None |
# | XGBoost                      |         0.00        |                        |n_estimators=1000 |
# | Multi Layer Perceptron       |         0.00        |                        |batch_size=8,depth=2,dropout_rate=0.2,nodes=250 |
#
# ### <center> 3 year rate </center>
# |               Model          |  Test Accuracy (%)  | Test weighted f1-score | Hyperparameters |
# | :--------------------------- | ------------------- | ---------------------: | --------------- |
# | Random Classifier            |         53.3        |          0.50          |       N/A       |
# | Logistic Regression          |         53.3        |          0.55          |       N/A       |
# | Support Vector Machine       |         52.6        |          0.55          |       N/A       |
# | Random Forest                |         0.00        |                        |n_estimators=3000, max_depth=None |
# | XGBoost                      |         0.00        |                        |n_estimators=1000 |
# | Multi Layer Perceptron       |         0.00        |                        |batch_size=8,depth=2,dropout_rate=0.2,nodes=250 |
#
# ### <center> S&P-500 </center>
# |               Model          |  Test Accuracy (%)  | Test weighted f1-score | Hyperparameters |
# | :--------------------------- | ------------------- | ---------------------: | --------------- |
# | Random Classifier            |         49.2        |          0.50          |       N/A       |
# | Logistic Regression          |         57.7        |          0.58          |       N/A       |
# | Support Vector Machine       |         56.7        |          0.57          |       N/A       |
# | Random Forest                |         0.00        |                        |n_estimators=3000, max_depth=None |
# | XGBoost                      |         0.00        |                        |n_estimators=1000 |
# | Multi Layer Perceptron       |         0.00        |                        |batch_size=8,depth=2,dropout_rate=0.2,nodes=250 |

# %% [markdown]
# ## Results
#
# The following results were achieved on the independent test set on the 1 year rate, 3 year rate and S&P-500 index. Note that only the 10000 most common words were included in the vocabulary, to reduce the dimensionality.
#
# |               Model          | Data |  Test Accuracy (%)  | Test weighted f1-score | Hyperparameters |
# | :--------------------------- | ---- | ------------------- | ---------------------: | --------------- |
# | Random Classifier| 1 year rate <br>3 year rate <br> S&P-500|62<br>53.3<br>49.2| 0.487<br>0.50<br>0.50 | N/A |
# | Logistic Regression          |      |         0.00        |                        |       N/A       |
# | Linear Discriminant Analysis |      |         0.00        |                        |       N/A       |
# | Support Vector Machine       |      |         0.00        |                        |       N/A       |
# | Random Forest                |      |         0.00        |                        |n_estimators=3000, max_depth=None |
# | XGBoost                      |      |         0.00        |                        |n_estimators=1000 |
# | Multi Layer Perceptron       |      |         0.00        |                        |batch_size=8,depth=2,dropout_rate=0.2,nodes=250 |
