# %%
from statsmodels.tsa.arima_model import ARMA
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm
from datetime import timedelta
import warnings

# %%
ONEDRIVE_PATH = Path(r"C:\Users\gusta\Kidbrooke Advisory Ab\KidbrookeOneDrive - Gustaf Backman exjobb")
# Read the financial data 
fin_path = ONEDRIVE_PATH / "Input Data/stock_data.pkl"
fin_data = pd.read_pickle(fin_path)
fin_data = fin_data.loc['2006-09-01' : '2013-11-22']

# Create dataframe with percental difference 
fin_pct = fin_data.pct_change()
fin_pct = fin_pct.drop(index=fin_pct.index[0])

# %%
news_path = ONEDRIVE_PATH / "Input Data/financial_headlines_20061020-20131119.pkl"
news_data = pd.DataFrame(pd.read_pickle(news_path))
news_data.set_index('date',inplace=True)

news_dates = news_data.index.drop_duplicates()
fin_dates = fin_data.index.drop_duplicates

# Find the dates which are present in both the financial data and news data
valid_dates = []
for date in news_dates: 
    if date in fin_data.index: 
        valid_dates.append(date)

# %%
plt.plot(fin_pct['1 YEAR'],label='1 YEAR')
plt.legend() 
plt.show() 
plt.plot(fin_pct['3 YEAR'], label='3 YEAR')
plt.legend() 
plt.show()
plt.plot(fin_pct['S&P'], label='S&P')
plt.legend() 
plt.show()

# %%
with warnings.catch_warnings(): 
    warnings.filterwarnings('error')
    try:
        temp_arma = ARMA(fin_pct.loc[:valid_dates[10]]['1 YEAR'],order=(1,1))
        temp_fit = temp_arma.fit()
    except Warning as e: 
        if str(e) == "No frequency information was provided, so inferred frequency B will be used.":
        pass
# Out:
# HÄR ÄR HAN

# %%
def try_fit(data,start,maxiter=1000,disp=0,internal_request=False): 
    # Test several optimization routines to get convergence
    with warnings.catch_warnings():
        warnings.filterwarnings('error')
        try: 
            m = ARMA(data,order=(1,1))
            m_fit = m.fit(start_params=start,maxiter=maxiter,solver="powell",disp=disp)
            return m_fit
        except Warning as e: 
            pass
        try: 
            m = ARMA(data,order=(1,1))
            m_fit = m.fit(start_params=start,maxiter=maxiter,solver="lbfgs",disp=disp)
            return(m_fit)
        except Warning as e: 
            pass
        try:
            m = ARMA(data,order=(1,1))
            m_fit = m.fit(start_params=start,maxiter=maxiter,solver="bfgs",disp=disp)
            return(m_fit)
        except Warning as e: 
            pass
        try:
            m = ARMA(data,order=(1,1))
            m_fit = m.fit(start_params=start,maxiter=maxiter,solver="newton",disp=disp)
            return(m_fit)
        except Warning as e: 
            pass
        try:
            m = ARMA(data,order=(1,1))
            m_fit = m.fit(start_params=start,maxiter=maxiter,solver="nm",disp=disp)
            return(m_fit)
        except Warning as e: 
            pass
        try:
            m = ARMA(data,order=(1,1))
            m_fit = m.fit(start_params=start,maxiter=maxiter,solver="cg",disp=disp)
            return(m_fit)
        except Warning as e: 
            pass
        try:
            m = ARMA(data,order=(1,1))
            m_fit = m.fit(start_params=start,maxiter=maxiter,solver="ncg",disp=disp)
            return(m_fit)
        except Warning as e: 
            pass
    if not internal_request:
        return try_fit(data,start=(0.5,0.5),maxiter=2*maxiter, internal_request=True)
    else:
        # If no solution was found after two tries with different start_params
        # and solvers, we'll just return a suboptimal solution. 
        print("Suboptimal solution returned.")
        m = ARMA(data,order=(1,1))
        m_fit = m.fit(start_params=start,maxiter=maxiter,solver="ncg",disp=disp)
        return m_fit

# %% [markdown]
# ### Next day predictions
# We fit a model given the filtration at time $t$ and then make a prediction. Since the prediction are linear in time, a negative prediction for day $k$ implies a negative prediction for day $k + \delta$ for all $\delta$.

# %%
fin_pct.loc[:valid_dates[50]]['1 YEAR'].values
# Out:
# array([ 0.        ,  0.00601202,  0.        ,  0.        , -0.00398406,
#         0.006     , -0.00198807, -0.0059761 ,  0.00601202,  0.00199203,
#         0.00198807, -0.00992063,  0.00200401, -0.014     , -0.00608519,
#        -0.00408163,  0.00614754, -0.00407332,  0.00204499,  0.00204082,
#        -0.00203666,  0.        , -0.00612245,  0.00616016,  0.00816327,
#         0.        ,  0.01214575,  0.004     ,  0.00199203,  0.00397614,
#         0.        , -0.0019802 ,  0.        ,  0.00198413,  0.        ,
#         0.00792079,  0.00196464, -0.00392157, -0.00393701, -0.00790514,
#         0.00199203, -0.00795229, -0.00801603,  0.0040404 ,  0.01810865,
#         0.        , -0.00592885, -0.00198807,  0.        , -0.00199203,
#         0.00399202, -0.00397614,  0.00598802,  0.00396825, -0.00790514,
#         0.        ,  0.        , -0.00199203,  0.        , -0.00199601,
#         0.        , -0.004     ,  0.        , -0.00803213, -0.01417004,
#         0.        , -0.00205339,  0.00823045,  0.        ,  0.01020408,
#        -0.0020202 , -0.00607287,  0.00814664,  0.0040404 , -0.00201207,
#         0.00201613, -0.00201207,  0.        , -0.00604839,  0.00608519,
#         0.        ,  0.00201613,  0.00402414,  0.00400802, -0.00199601])

# %%
m = ARMA(fin_pct.loc[:valid_dates[50]]['1 YEAR'].values,order=(1,1))
m_fit = m.fit()
m_fit.params
# Out:
# array([3.66030243e-05, 5.03688773e-02, 4.27188905e-03])

# %%
relative_preds = np.zeros((len(valid_dates), 3))
start = [0,0,0]
for i,date in enumerate(tqdm(valid_dates)): 
    for j,series in enumerate(fin_pct):
        temp_fit = try_fit(fin_pct.loc[:date][series].values,start)
        forec = temp_fit.forecast(steps=1)[0][0]
        relative_preds[i,j] = forec
        start = temp_mod.params
# Out:
#   1%|▌                                                                               | 13/1846 [00:08<19:17,  1.58it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-6a1396287399> in <module>
#       3 for i,date in enumerate(tqdm(valid_dates)):
#       4     for j,series in enumerate(fin_pct):
# ----> 5         temp_fit = try_fit(fin_pct.loc[:date][series].values,start)
#       6         forec = temp_fit.forecast(steps=1)[0][0]
#       7         relative_preds[i,j] = forec
#
# <ipython-input-35-5f790c691dbe> in try_fit(data, start, maxiter, disp, internal_request)
#       5         try:
#       6             m = ARMA(data,order=(1,1))
# ----> 7             m_fit = m.fit(start_params=start,maxiter=maxiter,solver="powell",disp=disp)
#       8             return m_fit
#       9         except Warning as e:
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\statsmodels\tsa\arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#     997                                        maxiter=maxiter,
#     998                                        full_output=full_output, disp=disp,
# --> 999                                        callback=callback, **kwargs)
#    1000         params = mlefit.params
#    1001
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\statsmodels\base\model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     524                                                        callback=callback,
#     525                                                        retall=retall,
# --> 526                                                        full_output=full_output)
#     527
#     528         # NOTE: this is for fit_regularized and should be generalized
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\statsmodels\base\optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     216                             disp=disp, maxiter=maxiter, callback=callback,
#     217                             retall=retall, full_output=full_output,
# --> 218                             hess=hessian)
#     219
#     220         optim_settings = {'optimizer': method, 'start_params': start_params,
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\statsmodels\base\optimizer.py in _fit_powell(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     558                                    full_output=full_output, disp=disp,
#     559                                    retall=retall, callback=callback,
# --> 560                                    direc=start_direc)
#     561     if full_output:
#     562         if not retall:
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\scipy\optimize\optimize.py in fmin_powell(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, direc)
#    2556             'return_all': retall}
#    2557
# -> 2558     res = _minimize_powell(func, x0, args, callback=callback, **opts)
#    2559
#    2560     if full_output:
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\scipy\optimize\optimize.py in _minimize_powell(func, x0, args, callback, xtol, ftol, maxiter, maxfev, disp, direc, return_all, **unknown_options)
#    2665         x2 = 2*x - x1
#    2666         x1 = x.copy()
# -> 2667         fx2 = squeeze(func(x2))
#    2668
#    2669         if (fx > fx2):
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\statsmodels\base\model.py in f(params, *args)
#     498
#     499         def f(params, *args):
# --> 500             return -self.loglike(params, *args) / nobs
#     501
#     502         if method == 'newton':
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\statsmodels\tsa\arima_model.py in loglike(self, params, set_sigma2)
#     808         method = self.method
#     809         if method in ['mle', 'css-mle']:
# --> 810             return self.loglike_kalman(params, set_sigma2)
#     811         elif method == 'css':
#     812             return self.loglike_css(params, set_sigma2)
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\statsmodels\tsa\arima_model.py in loglike_kalman(self, params, set_sigma2)
#     818         Compute exact loglikelihood for ARMA(p,q) model by the Kalman Filter.
#     819         """
# --> 820         return KalmanFilter.loglike(params, self, set_sigma2)
#     821
#     822     def loglike_css(self, params, set_sigma2=True):
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py in loglike(cls, params, arma_model, set_sigma2)
#     214         # TODO: this will not work for time-varying parameters
#     215         (y, k, nobs, k_ar, k_ma, k_lags, newparams, Z_mat, m, R_mat, T_mat,
# --> 216          paramsdtype) = cls._init_kalman_state(params, arma_model)
#     217         if np.issubdtype(paramsdtype, np.float64):
#     218             loglike, sigma2 = kalman_loglike.kalman_loglike_double(
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py in _init_kalman_state(cls, params, arma_model)
#     163         """
#     164         paramsdtype = params.dtype
# --> 165         y = arma_model.endog.copy().astype(paramsdtype)
#     166         k = arma_model.k_exog + arma_model.k_trend
#     167         nobs = arma_model.nobs
#
# KeyboardInterrupt:

# %%
relative_preds = np.zeros((len(valid_dates) - 1, 3))
for i,date in enumerate(tqdm(valid_dates)): 
    for j,series in enumerate(fin_pct):
        temp_mod = try_fit(fin_pct.loc[:valid_dates[50]]['1 YEAR'].values,start)
        
        with warnings.catch_warnings():
            warnings.filterwarnings('error')
            try:
                temp_arma = ARMA(fin_pct.loc[:date][series],order=(1,1))
                print("Fitting date",date,"series",series)
                temp_fit = temp_arma.fit() 
            except Warning as e: 
                if not str(e) == "No frequency information was provided, so inferred frequency B will be used.":
                    print(e)
                pass
            forec = temp_fit.forecast(steps=1)[0][0]
            relative_preds[i,j] = forec
# Out:
#  19%|██████████████▊                                                                | 346/1846 [00:03<00:15, 96.15it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-586b0da45980> in <module>
#       5             warnings.filterwarnings('error')
#       6             try:
# ----> 7                 temp_arma = ARMA(fin_pct.loc[:date][series],order=(1,1))
#       8                 print("Fitting date",date,"series",series)
#       9                 temp_fit = temp_arma.fit()
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, endog, order, exog, dates, freq, missing)
#     442     def __init__(self, endog, order, exog=None, dates=None, freq=None,
#     443                  missing='none'):
# --> 444         super(ARMA, self).__init__(endog, exog, dates, freq, missing=missing)
#     445         # GH 2575
#     446         array_like(endog, 'endog')
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py in __init__(self, endog, exog, dates, freq, missing, **kwargs)
#      48
#      49         # Date handling in indexes
# ---> 50         self._init_dates(dates, freq)
#      51
#      52     def _init_dates(self, dates=None, freq=None):
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py in _init_dates(self, dates, freq)
#     152                 # If no frequency, try to get an inferred frequency
#     153                 if freq is None and index.freq is None:
# --> 154                     freq = index.inferred_freq
#     155                     # If we got an inferred frequncy, alert the user
#     156                     if freq is not None:
#
# pandas\_libs\properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\pandas\core\indexes\extension.py in cached(self)
#      47
#      48             def cached(self):
# ---> 49                 return getattr(self._data, name)
#      50
#      51             cached.__name__ = name
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\pandas\core\arrays\datetimelike.py in inferred_freq(self)
#    1001             return None
#    1002         try:
# -> 1003             return frequencies.infer_freq(self)
#    1004         except ValueError:
#    1005             return None
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\pandas\tseries\frequencies.py in infer_freq(index, warn)
#     294             index = pd.DatetimeIndex(index.asi8)
#     295
# --> 296     inferer = _FrequencyInferer(index, warn=warn)
#     297     return inferer.get_freq()
#     298
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\pandas\tseries\frequencies.py in __init__(self, index, warn)
#     319
#     320         self.is_monotonic = (
# --> 321             self.index._is_monotonic_increasing or self.index._is_monotonic_decreasing
#     322         )
#     323
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\pandas\core\indexes\base.py in is_monotonic_increasing(self)
#    1601         False
#    1602         """
# -> 1603         return self._engine.is_monotonic_increasing
#    1604
#    1605     @property
#
# KeyboardInterrupt:

# %%
relative_preds
# Out:
# array([[0.0024771, 0.0024771, 0.0024771],
#        [0.0024771, 0.0024771, 0.0024771],
#        [0.0024771, 0.0024771, 0.0024771],
#        ...,
#        [0.0024771, 0.0024771, 0.0024771],
#        [0.0024771, 0.0024771, 0.0024771],
#        [0.0024771, 0.0024771, 0.0024771]])
