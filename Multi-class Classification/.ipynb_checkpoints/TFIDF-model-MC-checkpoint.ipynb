# %%
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import optimizers
from pathlib import Path
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from nltk.tokenize import word_tokenize
from nltk import FreqDist
from sklearn.metrics import confusion_matrix, plot_confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
import seaborn as sn
import os
import io
import pickle
import random
import itertools
from importnb import Notebook, reload
with Notebook(): 
    import Utilities

# %%
config = {
    'start_date': '2006-10-20',
    'end_date': '2013-11-19',
    'lookback': 1,    # Lookback is set to 1 since we only consider one previous day here
    'delay': 5,
    'p': 1,
    'd': 1,
    'q': 1,
    'series': '1 YEAR',
}

# %%
# Load data
news_path = Path(os.path.dirname(os.getcwd())) / "Datasets/data/financial_headlines_20061020-20131119.pkl"
news_data = pd.DataFrame(pd.read_pickle(news_path))
news_data.set_index('date',inplace=True)
# Concatinate daily
text = Utilities.preprocess_text(news_data)

# %%
# Create a matrix of size (n,vocab_size)
count_vec = CountVectorizer()
count_vec.fit(text)
x_count = count_vec.transform(text)

tfidf_vec = TfidfTransformer()
tfidf_vec.fit(x_count)
x_tf = tfidf_vec.transform(x_count)
print("Shape of x:",x_tf.shape)
# Out:
# Shape of x: (2582, 23560)

# %%
# Pick thresholds for the classes. Observe that these are normalized values, 
# so it's the distribution rather than the numbers that's important. 
thresholds = [-0.005,-0.002,0.002,0.005]
nbr_classes = len(thresholds) + 1
y = Utilities.load_multiclass_labels(config,thresholds,plot=True)
# Out:
# Loaded previously constructed labels.

# %%
# Need to remove some rows from the word embedding-matrix,
# these numbers are specified in Utilities.fit_all_models()
rm_start_rows = max(config['lookback'],5) + 1
rm_end_rows = config['delay']
x_tf = x_tf[rm_start_rows : - rm_end_rows]

# %%
# Shuffle for training and testing 
(x_train,y_train), (x_test, y_test) = Utilities.shuffle_and_partition(x_tf.todense(),y, test_part=0.2)
print("Shape of x_train: ",x_train.shape)
print("Shape of y_train: ",y_train.shape)
# Out:
# Shape of x_train:  (2056, 23560)
# Shape of y_train:  (2056,)

# %%
def create_nn(n_nodes, lr=0.001): 
    # n_nodes is a list with the number of nodes per layer, starting from the input 
    model = Sequential() 
    model.add(Dense(n_nodes[0], activation='relu', input_shape=[x_train.shape[-1]]))
    if len(n_nodes) > 1: 
        for n in n_nodes: 
            model.add(Dense(n,activation='relu'))
    model.add(Dense(nbr_classes, activation='softmax'))
    rms = optimizers.RMSprop(learning_rate=lr)
    model.compile(optimizer=rms, loss='sparse_categorical_crossentropy', metrics=['acc'])
    return model

def train_and_format(x,y,bs,epochs, results, layers, nodes,lr):
    name = f"{bs}_{layers}_{nodes}"
    temp_history = model.fit(x, y, batch_size=bs, validation_split=0.2, epochs = epochs,verbose=0)
    return results.append(pd.Series([np.mean(temp_history.history['val_acc'][-5:]),
                                                temp_history, model, layers, 
                                                nodes, bs, lr], 
                                                name=name,
                                    index=['Mean Val Acc','History','Model','Layers','Nodes','Batch Size','Learning Rate']))

# %%
n_layers = [2]
n_nodes = [25, 50, 100, 200, 300, 400, 500]
learning_rates = [0.0001]
batch_sizes = [12]
epochs = 20
results = pd.DataFrame(columns=['Mean Val Acc','History','Model', 'Layers', 'Nodes','Batch Size','Learning Rate'])
n_configs = sum([len(n_nodes)**l for l in n_layers]) * len(batch_sizes) * len(learning_rates)
ctr = 0
print('Testing {} combinations. '.format(n_configs))
for layers in n_layers:
    if layers == 1: node_configs = list(itertools.product(n_nodes))
    elif layers == 2: node_configs = list(itertools.product(n_nodes, n_nodes))
    elif layers == 3: node_configs = list(itertools.product(n_nodes, n_nodes, n_nodes))
    elif layers == 4: node_configs = list(itertools.product(n_nodes, n_nodes, n_nodes, n_nodes))
    for bs in batch_sizes: 
        for temp_nodes in node_configs:
            for lr in learning_rates: 
                ctr += 1 
                model = create_nn(temp_nodes, lr)
                results = train_and_format(x_train, y_train, bs, epochs, results, layers, temp_nodes, lr)
                print("{} %     ".format(round(100 * ctr / n_configs,2)),end='\r')
# Out:
# Testing 49 combinations.
# 48.98 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-104-c506294db536> in <module>
#      18                 ctr += 1
#      19                 model = create_nn(temp_nodes, lr)
# ---> 20                 results = train_and_format(x_train, y_train, bs, epochs, results, layers, temp_nodes, lr)
#      21                 print("{} %     ".format(round(100 * ctr / n_configs,2)),end='\r')
#      22
#
# <ipython-input-103-f010ca4062d0> in train_and_format(x, y, bs, epochs, results, layers, nodes, lr)
#      13 def train_and_format(x,y,bs,epochs, results, layers, nodes,lr):
#      14     name = f"{bs}_{layers}_{nodes}"
# ---> 15     temp_history = model.fit(x, y, batch_size=bs, validation_split=0.2, epochs = epochs,verbose=0)
#      16     return results.append(pd.Series([np.mean(temp_history.history['val_acc'][-5:]),
#      17                                                 temp_history, model, layers,
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\tensorflow_core\python\eager\def_function.py in __call__(self, *args, **kwds)
#     566         xla_context.Exit()
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#     570     if tracing_count == self._get_tracing_count():
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\tensorflow_core\python\eager\def_function.py in _call(self, *args, **kwds)
#     597       # In this case we have created variables on the first call, so we run the
#     598       # defunned version which is guaranteed to never create variables.
# --> 599       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     600     elif self._stateful_fn is not None:
#     601       # Release the lock early so that multiple threads can perform the call
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    2361     with self._lock:
#    2362       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2363     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2364
#    2365   @property
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\tensorflow_core\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1609          if isinstance(t, (ops.Tensor,
#    1610                            resource_variable_ops.BaseResourceVariable))),
# -> 1611         self.captured_inputs)
#    1612
#    1613   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# C:\ProgramData\Anaconda3\envs\nlpenv\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
k = 3
print("Top {} configs: ".format(k))
k_best = np.argpartition(results['Mean Val Acc'],-k)[-k:]
results.iloc[k_best]
# Out:
# Top 3 configs:
#                 Mean Val Acc  \
# 12_2_(50, 100)      0.439806
# 12_2_(200, 50)      0.441748
# 12_2_(25, 100)      0.446602
#
#                                                           History  \
# 12_2_(50, 100)  <tensorflow.python.keras.callbacks.History obj...
# 12_2_(200, 50)  <tensorflow.python.keras.callbacks.History obj...
# 12_2_(25, 100)  <tensorflow.python.keras.callbacks.History obj...
#
#                                                             Model Layers  \
# 12_2_(50, 100)  <tensorflow.python.keras.engine.sequential.Seq...      2
# 12_2_(200, 50)  <tensorflow.python.keras.engine.sequential.Seq...      2
# 12_2_(25, 100)  <tensorflow.python.keras.engine.sequential.Seq...      2
#
#                     Nodes Batch Size  Learning Rate
# 12_2_(50, 100)  (50, 100)         12         0.0001
# 12_2_(200, 50)  (200, 50)         12         0.0001
# 12_2_(25, 100)  (25, 100)         12         0.0001

# %%
for i in k_best: 
    print(f"Nodes: {results.iloc[i]['Nodes']}, Mean validation accuracy: {results.iloc[i]['Mean Val Acc']}")
    plt.subplot(121)
    plt.plot(results.iloc[i]['History'].history['val_loss'],label='Val loss')
    plt.plot(results.iloc[i]['History'].history['loss'],label='Training loss')
    plt.legend()
    plt.subplot(122)
    plt.plot(results.iloc[i]['History'].history['val_acc'],label='Val acc')
    plt.plot(results.iloc[i]['History'].history['acc'],label='Training acc')
    plt.legend()
    plt.show()
    results.iloc[i]['Model'].evaluate(x_test,y_test,verbose=0)
    # Calculate the predictions on the test set 
    y_test_pred_prob = model.predict(x_test)
    y_test_pred = np.zeros(len(y_test))
    for i,row in enumerate(y_test_pred_prob): 
        y_test_pred[i] = np.argmax(row)
        
    conf_mat = confusion_matrix(y_test,y_test_pred,normalize='pred')
    plt.subplot(121)
    ax = sn.heatmap(conf_mat)
    ax.set_ylabel("True values")
    ax.set_xlabel("Predicted values")
    Utilities.plot_multi_predictions(y_test_pred, nbr_classes,subplot=122,show=True)
# Out:
# Nodes: (50, 100), Mean validation accuracy: 0.439805805683136
# Nodes: (200, 50), Mean validation accuracy: 0.4417475759983063
# Nodes: (25, 100), Mean validation accuracy: 0.4466019570827484

# %%
with Notebook(): 
    reload(Utilities)
